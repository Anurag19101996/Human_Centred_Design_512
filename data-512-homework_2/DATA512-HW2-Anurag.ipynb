# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import json, time, urllib.parse
import requests

# %%
#reading csv file for politicians
pol = pd.read_csv('politicians_by_country_AUG.2024.csv')

# %%
#viweing the dataframe
pol.head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %% [markdown]
# Getting a preliminary view of the politicans in the dataset

# %%
politicians = [name for name in pol['name']]

# %%
politicians
# Out:
# ['Majah Ha Adrif',
#  'Haroon al-Afghani',
#  'Tayyab Agha',
#  'Khadija Zahra Ahmadi',
#  'Aziza Ahmadyar',
#  'Muqadasa Ahmadzai',
#  'Mohammad Sarwar Ahmedzai',
#  'Amir Muhammad Akhundzada',
#  'Nasrullah Baryalai Arsalai',
#  'Abdul Rahim Ayoubi',
#  'Ismael Balkhi',
#  'Abdul Baqi Turkistani',
#  'Mohammad Ghous Bashiri',
#  'Jan Baz',
#  'Bashir Ahmad Bezan',
#  'Rafiullah Bidar',
#  'Mohammad Siddiq Chakari',
#  'Cheragh Ali Cheragh',
#  'Nasir Ahmad Durrani',
#  'Muhammad Hashim Esmatullahi',
#  'Ezatullah (Nangarhar)',
#  'Aimal Faizi',
#  'Gajinder Singh Safri',
#  'Sharif Ghalib',
#  'Hashmat Ghani Ahmadzai',
#  'Abdul Ghani Ghani',
#  'Ghulam Ghaus',
#  'Ghulam Muhammad Ghobar',
#  'Mohammad Gul (Helmand Council)',
#  'Sayed Yousuf Halim',
#  'Rangina Hamidi',
#  'Sayed Zafar Hashemi',
#  'Qutbuddin Hilal',
#  'Mahboba Hoqomal',
#  'Musa Hotak',
#  'Mirza Muhammad Ismail',
#  'Sayed Jalal',
#  'Said Tayeb Jawad',
#  'Sayed Jalal Karim',
#  'Hafizullah Shabaz Khail',
#  'Masoud Khalili',
#  'Mohammad Khan (athlete)',
#  'Samoud Khan',
#  'Baran Khan Kudezai',
#  'Azizullah Lodin',
#  'Razaq Mamoon',
#  'Fazel Ahmed Manawi',
#  'Moeen Marastial',
#  'Ahmad Wali Massoud',
#  'Mohammad Daud Miraki',
#  'Abdul Sattar Mirzakwal',
#  'Abdul Karim Misaq',
#  'Ali Mohammad (politician)',
#  'Nasruddin Mohseni',
#  'Davood Moradian',
#  'Zalmai Mujadidi',
#  'Sardar Mohammad Nadir Naeem',
#  'Daoud Naji',
#  'Gholam Rabani Nasher',
#  'Ghulam Faroq Nijrabi',
#  'Zabih-U-llah Ghazi Noristani',
#  'Mohammed Tahir Omar',
#  'Mohammed Qalamuddin',
#  'Ghulam Mohammad Rigi',
#  'Ghulam Hassan Safi',
#  'Hanifa Safi',
#  'Mohammed Zia Salehi',
#  'Abdul Majid Samim',
#  'Saber Sangar',
#  'Sayed Nasim Mihanparast',
#  'Suhail Shaheen',
#  'Fazal Hadi Shinwari',
#  'Baktash Siawash',
#  'Hasan Ali Sultani',
#  'Mohammad Hashem Taufiqui',
#  'Pacha Gul Wafadar',
#  'Wahidullah Waissi',
#  'Ahmadullah Wasiq',
#  'Gul Ahmmad Yama',
#  'Abdul Salam Zaeef',
#  'Abdul Zahir (Konar Education Minister)',
#  'Mohammed Zaman',
#  'Ziauddin (Afghan militia leader)',
#  'Qari Ziauddin',
#  'Abdul Ghafor Zori',
#  'Ali Pasha of Gusinje',
#  'Ylli Asllani',
#  'Azis Tahir Ajdonati',
#  'Bislim Bajgora',
#  'Kastriot Berissa',
#  'Bardhok Biba',
#  'Kostandin Boshnjaku',
#  'Spartak Braho',
#  'Safet Butka',
#  'Uran Butka',
#  'Refo Çapari',
#  'Neritan Ceka',
#  'Hysni Curri',
#  'Ibrahim Dalliu',
#  'Niazi Demi',
#  'Abdurrahman Dibra',
#  'Bujar Dida',
#  'Ahmed Dino',
#  'Rasih Dino',
#  'Ferhat Bey Draga',
#  'Nexhip Draga',
#  'Aqif Pasha Elbasani',
#  'Abas Ermenji',
#  'Qamil Musa Haxhi Feza',
#  'Themistokli Gërmenji',
#  'Sabri Godo',
#  'Mihal Grameno',
#  'Aćif Hadžiahmetović',
#  'High Council of Regency',
#  'Kurt Agë Kadiu',
#  'Mehmed Kalakula',
#  'Alfred Karamuço',
#  'Ibrahim Karbunara',
#  'Ali Këlcyra',
#  'Bajram Kelmendi',
#  'Kristo Kirka',
#  'Elez Koçi',
#  'Xhelal Koprëncka',
#  'Kryeziu family',
#  'Artur Kuko',
#  'Xhavid Leskoviku',
#  'Sabit Lulo',
#  'Gjon Markagjoni',
#  'Tefik Mborja',
#  'Hysni Milloshi',
#  'Musa Qazimi',
#  'Mustafa Ndroqi',
#  'Behxhet Nepravishta',
#  'Adrian Neritani',
#  'Sali Nivica',
#  'Thoma Orologa',
#  'Bedri Pejani',
#  'Kadri Prishtina',
#  'Ymer Prizreni',
#  'Avni Rustemi',
#  'Chatin Sarachi',
#  'Nebi Sefa',
#  'Eduard Shalsi',
#  'Ylli Vesel Shehu',
#  'Athanas Shundi',
#  'Xhelal Sveçla',
#  'Mehmet Tahsini',
#  'Ibrahim Temo',
#  'Afrim Tole',
#  'Syreja Vlora',
#  'Visarion Xhuvani',
#  'Visar Ymeri',
#  'Abdyl Ypi',
#  'Xhezair Zaganjori',
#  'Menduh Zavalani',
#  'Abdelkader Zoukh',
#  'Chaâbane Aït Abderrahim',
#  'Ali Aoun',
#  'Basma Azouar',
#  'Mohamed Seghir Babes',
#  'Noureddine Bahbouh',
#  'Lamine Bechichi',
#  'Aïssa Bekkai',
#  'Abdelhakim Belabed',
#  'Mohamed Tarek Belaribi',
#  'Kamel Beldjoud',
#  'Aboubakr Belkaid',
#  'Youcef Belmehdi',
#  'Mohamed Cherif Belmihoub',
#  'Mohamed Belouizdad',
#  'Benaouda Hadj Hacène Bachterzi',
#  'Souad Bendjaballah',
#  'Abdelkrim Benmbarek',
#  'Mohamed Bensalam',
#  'Fayçal Bentaleb',
#  'Ahmed Bidani',
#  'Kamel Bidari',
#  'Rachid Bladehane',
#  'Saïd Boualam',
#  'Rabah Bouaziz',
#  'Abdeslam Bouchouareb',
#  'Ibrahim Boughali',
#  'Yahia Boukhari',
#  'Mohamed Bouslimani',
#  'Foued Chehat',
#  'Hamza Al Sid Cheikh',
#  'Hocine Cherhabil',
#  'Abderrahmane Meziane Chérif',
#  'Saïd Chibane',
#  'Brahim Chibout',
#  'Youcef Chorfa',
#  'Fazia Dahleb',
#  'Taha Derbal',
#  'Nassim Diafat',
#  'Mokhtar Didouche',
#  'Bouras Djamel',
#  'Fatiha Serour',
#  'Ahmed Hamiani',
#  'Nadir Kassab',
#  'Brahim Djamel Kassali',
#  'Kaoutar Krikou',
#  'Sassi Lamouri',
#  'Mohamed Maghlaoui',
#  'Amar Makhloufi',
#  'Yassine Merabi',
#  'Brahim Merad',
#  'Bachir Messaitfa',
#  'Azzedine Mihoubi',
#  'Mohamed Ali Boughazi',
#  'Amar Mohammedi',
#  'Samia Moualfi',
#  'Soraya Mouloudji',
#  'Yacine Oualid',
#  'Cherif Rahmani',
#  'Lakhdar Rakhroukh',
#  'Laid Rebiga',
#  'Kamel Rezig',
#  'Salim Saadi',
#  'Abdelhak Saihi',
#  'Hichem Sofiane Salaouatchi',
#  'Naima Salhi',
#  'Abderezak Sebgag',
#  'Abderrachid Tabbi',
#  'Karim Bibi Triki',
#  'Layachi Yaker',
#  'Ahmed Zeghdar',
#  'Adão Francisco Correia de Almeida',
#  'Ana Paula Chantre Luna de Carvalho',
#  'Alexandre Sebastião André',
#  'Paulino Baptista',
#  'Bernarda Gonçalves Martins',
#  'João Baptista Borges',
#  'Carolina Cerqueira',
#  'Arlete Chimbinda',
#  'Kafundanga Chingunji',
#  'Jeremias Chitunda',
#  'Abel Chivukuvuku',
#  'Fiel Domingos Constantino',
#  'Adalberto Costa Júnior',
#  'Adjany Costa',
#  'Álvaro Arnaldo Craveiro',
#  'Raul Danda',
#  'Diamantino Pedro Azevedo',
#  'Faustina Fernandes Inglês de Almeida Alves',
#  'Abraão Gourgel',
#  'Jofre Van-Dúnem Júnior',
#  'José Carvalho da Rocha',
#  'José Luis de Matos',
#  'Kambamba Kulaxingo',
#  'Jesus Faria Maiato',
#  'Manuel Neto da Costa',
#  'Manuel Tavares de Almeida',
#  'Marcos Alexandre Nhunga',
#  'Maria Cândida Pereira Teixeira',
#  'Maria do Rosário Teixeira de Alva Sequeira Bragança Sambo',
#  'David Mendes',
#  'Saíde Mingas',
#  'Fernando Faustino Muteka',
#  'Pedro Mutinde',
#  'José Ndele',
#  'Ana Paula Sacramento Neto',
#  'Daniel Ntongi-Nzinga',
#  'Paula Cristina Francisco Coelho',
#  'Pedro Pedalé',
#  'Elias Salupeto Pena',
#  'Johnny Eduardo Pinnock',
#  'Santana André Pitra',
#  'Francisco Manuel Monteiro de Queiróz',
#  'José Aníbal Lopes Rocha',
#  'José da Rocha',
#  'Rosa Luís de Sousa Micolo',
#  'Luís Gomes Sambo',
#  'Branca Manuel Espirito Santo',
#  'João Ernesto dos Santos',
#  'José Filomeno dos Santos',
#  'Jonas Savimbi',
#  'Pinda Simão',
#  'Manuel Bernardo de Sousa',
#  'Augusto da Silva Tomás',
#  'José Jacinto Van-Dúnem',
#  'José Vieira Dias Van-Dúnem',
#  'Luzia Inglês Van-Dúnem',
#  'Manuel Vicente',
#  'Mfulupinga Nlando Victor',
#  'Clement Antonio',
#  'Randolph Beazer',
#  'Studiation Brown',
#  'Alex Browne (politician)',
#  "Colin O'Neil Browne",
#  'James Carlisle',
#  'Gail Christian',
#  'Mackenzie Frank',
#  'Osbert Richard Frederick',
#  'Caleb Gardiner',
#  'Shenella Mary Shadida Govia',
#  'William Haynes-Smith',
#  'Tim Hector',
#  'Cheryl Mary Clare Hurst',
#  'Wilfred Jacobs',
#  'Rick James (actor)',
#  'Kiz Johnson',
#  'Fabian Jones',
#  'Johnathan Joseph (politician)',
#  'Kelvin Simon',
#  'Harold Lovell',
#  'Edmond Mansoor',
#  'David Massiah',
#  'Joanne Massiah',
#  'Dwayne George',
#  'Knacyntar Nedd',
#  'Melford Nicholas',
#  'Shawn Nicholas',
#  'Bernard Percival',
#  'Jamale Pringle',
#  'Philip Shoul',
#  'Rawdon Turner',
#  'Alincia Williams-Grant',
#  'Juan Alemann',
#  'Germán Alfaro',
#  'Joaquín Samuel de Anchorena',
#  'Juan Agustín Augier',
#  'Uladislao Augier',
#  'Marco Aurelio Avellaneda',
#  'Joaquín Belgrano',
#  'Antonio Bermejo',
#  'Antonio Beruti',
#  'Héctor Bidonde',
#  'Silvano Bores',
#  'Exequiel Bustillo',
#  'Mario Cafiero',
#  'Alberto Manuel Campos',
#  'Alejo Castex',
#  'Dámaso Centeno',
#  'Rossana Chahla',
#  'Lázaro Chiappe',
#  'Carlos Corach',
#  'Jorge Coscia',
#  'Carlos de la Rosa',
#  'Juan Carlos Del Bello',
#  'Luis L. Domínguez',
#  'Máximo Etchecopar',
#  'Héctor Toty Flores',
#  'Guillermo Francos',
#  'Juan Fugl',
#  'Santiago Gallo',
#  'Manuel José García',
#  'Juan José Gómez Centurión',
#  'Luis Carlos Gómez Centurión',
#  'Martín Guzmán',
#  'Federico Helguera',
#  'Fernando Iglesias (Argentine politician)',
#  'Ricardo Kennedy',
#  'Carlos Kunkel',
#  'Norberto La Porta',
#  'Andrés Larroque',
#  'Julián de Leyva',
#  'Mónica López (politician)',
#  'Lucio Victorio Mansilla',
#  'Nicolás Massot',
#  'Martín Menem',
#  'Juan Mignaburu',
#  'Guillermo Montenegro',
#  'Mariano Moreno',
#  'Marcelo Muniagurria',
#  'Fernando Nadra',
#  'Rómulo Sebastián Naón',
#  "Santiago G. O'Farrell",
#  'Alfredo Olmedo',
#  'Miguel Ángel Pesce',
#  'Carlos Petroni',
#  'Alejo Peyret',
#  'Aldo Pignanelli',
#  'Abel Posse',
#  'Enrique S. Quintana',
#  'Amán Rawson',
#  'Martín Sabbatella',
#  'Juan Pablo Schiavi',
#  'Héctor Tizón',
#  'Claudio Uberti',
#  'Arístides Villanueva',
#  'Jorge Yoma',
#  'Ashot Arsenyan',
#  'Vigen Chitechyan',
#  'Hayk Chobanyan',
#  'Gurgen Egiazaryan',
#  'Parunak Ferukhan',
#  'Gevorg Ghazaryan (politician)',
#  'Andrias Ghukasyan',
#  'Aram Grigoryan (politician)',
#  'Vahagn Hovakimyan',
#  'Tigran Karapetyan',
#  'Tigran Khzmalyan',
#  'Mikayel Kotanyan',
#  'Hrant Maloyan',
#  'Khachatur Malumian',
#  'Aram Manukyan',
#  'Gevorg Melik-Karagyozyan',
#  'Vahan Minakhoryan',
#  'Ruben Miroyan',
#  'Ruben Mirzakhanyan',
#  'Badal Muradyan',
#  'Narine Tukhikyan',
#  'Gabriel Noradoungian',
#  'Israel Ori',
#  'Paul Paul',
#  'Garo Paylan',
#  'Genrikh Poghosyan',
#  'Ishkhan Saghatelyan',
#  'Karen Sargsyan (sociologist)',
#  'Martiros Sarukhanyan',
#  'Vartkes Serengülian',
#  'Suren Shadunts',
#  'Ohannes Tchekidjian',
#  'Hrayr Tovmasyan',
#  'Usub Bek Temuryan',
#  'Kegham Vanigian',
#  'Serop Zakaryan',
#  'Alfons Adam',
#  'Ingo Appelt',
#  'Maximilian Anton Karl, Count Baillet de Latour',
#  'Heinrich Alfred Barb',
#  'Leopold Berchtold',
#  'Joseph Buttinger',
#  'Prince Carl of Solms-Braunfels',
#  'Count Václav Antonín Chotek of Chotkov and Vojnín',
#  "Citizens' Ministry",
#  'Richard von Coudenhove-Kalergi',
#  'Franz Dinghofer',
#  'George Abraham von Dyhrn',
#  'Eduard von Grebmer zu Wolfsthurn',
#  'Barbara Eibinger-Miedl',
#  'Hans Ferlitsch',
#  'Friedhelm Frischenschlager',
#  'Walter Guggenberger',
#  'Ulrich Habsburg-Lothringen',
#  'Ernst Hampel (politician)',
#  'Hans Peter Haselsteiner',
#  'Friedrich Wilhelm von Haugwitz',
#  'Eduard Hedvicek',
#  'Hermann Stern',
#  'Jürgen Himmelbauer',
#  'Anton Hofer',
#  'Andreas Hörtnagl',
#  'Franz Jetzinger',
#  'Konstantin Jireček',
#  'Hugo Jury',
#  'Joseph Kenner',
#  'Theodor Kery',
#  'Michael Killisch-Horn',
#  'Sophia Kircher',
#  'Hubert Klausner',
#  'Martin Kocher',
#  'Józef Kożdoń',
#  'Gottfried von Kühnelt-Leddihn',
#  'Franz Leitner (politician)',
#  'Elmar Lichtenegger',
#  'Julius Lippert (historian)',
#  'Reinhold Lopatka',
#  'Karl Lütgendorf',
#  'Jürgen Mandl',
#  'Renate Mann',
#  'Ferdinand Mannlicher',
#  'Christoph Matznetter',
#  'Johann Gregor Memhardt',
#  'Franz Moroder',
#  'Heinz Nittel',
#  'Heidemaria Onodi',
#  'Brigitta Pallauf',
#  'Wladimir von Pawlowski',
#  'Johann Anton von Pergen',
#  'Gerhard Pfanzelter',
#  'Walter Pfrimer',
#  'Leopold Poetsch',
#  'Thomas Prinzhorn',
#  'Gregor Razumovsky (activist)',
#  'Horst Rosenkranz',
#  'Emil Sax',
#  'Peter Schieder',
#  'Karl Schmitzer',
#  'Sonja Zwazl',
#  'Georg Adam, Prince of Starhemberg',
#  'Gundaker Thomas Starhemberg',
#  'Josef Staribacher',
#  'Peter Strasser (politician)',
#  'Julius Tandler',
#  'Leopold, Count von Thun und Hohenstein',
#  'Karl Freiherr von Vogelsang',
#  'Anton von Winzor',
#  'Gisela Wurm',
#  'Alexander Zach',
#  'Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau',
#  'Karl von Zinzendorf',
#  'Muzamil Abdullayev',
#  'Leyla Abdullayeva',
#  'Elchin Afandiyev',
#  'Fazail Agamali',
#  'Aliabbas Salahzade',
#  'Enver Alikhanov',
#  'Tarlan Aliyarbayov',
#  'Dilara Aliyeva',
#  'Araz Alizadeh',
#  'Ali Asadov',
#  'Ashraf Bey Taghiyev',
#  'Chimnaz Aslanova',
#  'Akram Aylisli',
#  'Sahil Babayev',
#  'Huseyngulu Baghirov',
#  'Bakhish bey Rustambeyov',
#  'Alovsat Bakhshiyev',
#  'Mirgasim Cheshmazer',
#  'Vilayat Eyvazov',
#  'Abdurrahman Fatalibeyli',
#  'Fazail Ibrahimli',
#  'Afshan Gadimbeyova',
#  'Garib Karimoğlu',
#  'Gudrat Gasanguliev',
#  'Mehrali Gasimov',
#  'Solomon Grobshtein',
#  'Teymur Guliyev',
#  'Mammad Gurbanov',
#  'Musa Hacigasimov',
#  'Asaf Hajiyev',
#  'Haji Molla Ahmad Nuruzade',
#  'Farhad Hajiyev',
#  'Hasan Majidov',
#  'Hasan Hasanli',
#  'Jamil Hasanli',
#  'Ali M. Hasanov',
#  'Zakir Hasanov',
#  'Ali Huseynli',
#  'Alisahib Huseynov',
#  'Ali Ibrahimov',
#  'Irshad Aliyev',
#  'Mamed Iskenderov',
#  'Vidadi Isgandarov',
#  'Ajdar Ismailov',
#  'Saftar Jafarov',
#  'Jeyhun Jalilov',
#  'Arastun Javadov',
#  'Rovshan Javadov',
#  'Anar Karimov',
#  'Boris Kevorkov',
#  'Gurban Khalilov',
#  'Ahmad Kordary',
#  'Lutfali bey Behbudov',
#  'Ilham Madatov',
#  'Makhmud Mamed-Guliev',
#  'Majnun Mammadov',
#  'Musa Mammadov',
#  'Ramin Mammadov',
#  'Elshad Mirbashir oghlu',
#  'Tahir Mirkishili',
#  'Movsum Samadov',
#  'Fuad Naghiyev',
#  'Eldar Namazov',
#  'Namig Nasrullayev',
#  'Siyavush Novruzov',
#  'Zahid Oruj',
#  'Sadig Rahimov',
#  'Suleyman Rahimov',
#  'Huseyn Rahmanov',
#  'Rovshen Rzayev',
#  'Hasan Seyidov',
#  'Hasan Seyidov (scientist)',
#  'Parviz Shahbazov',
#  'Mammad agha Shahtakhtinski',
#  'Abid Sharifov',
#  'Shirali Akhundov',
#  'Ikhtiyar Shirinov',
#  'Bakhtiyar Vahabzadeh',
#  'Vugar Mustafayev (minister)',
#  'Yusif Ziya Talibzadeh',
#  'Nurali Yusifbayli',
#  'Keith Bell (Bahamian politician)',
#  'Charles Carter (Bahamian journalist)',
#  'Harold Christie',
#  'Timothy Donaldson',
#  'Eugene Dupuch',
#  'Joseph Robert Love',
#  'McKell Bonaby',
#  'Pakesia Parker-Edgecombe',
#  'James Carmichael Smith (postmaster)',
#  'Mohammed Isa Al Abbasi',
#  'Abdulla Adel Fakhro',
#  'Abdullah bin Isa Al Khalifa',
#  'Ahmed Behzad (Bahrain)',
#  'Kamal Ahmed (politician)',
#  'Mohamed Ali Hasan Ali',
#  'Khalid Almoayed',
#  'Aymen Tawfeeq Almoayed',
#  'Nazar Al Baharna',
#  'Mahmood Al Bahrani',
#  'Ammar Al Bannai',
#  'Jawad Fairooz',
#  'Qasim Fakhro',
#  'Faisal al-Hamar',
#  'Nabeel bin Yaqub Al-Hamar',
#  'Isa bin Abdulrahman Al Hammadi',
#  'Jameel Humadan',
#  'Isa bin Ibrahim Al Khalifa',
#  'Fahmi al-Jowder',
#  'Saud Kanoo',
#  'Essam Khalaf',
#  'Abdullah bin Hamad bin Isa Al Khalifa',
#  'Ahmed bin Mohamed Al Khalifa',
#  'Ali bin Khalifa Al Khalifa',
#  'Hala bint Mohammed Al Khalifa',
#  'Ibrahim ibn Khalifa Al Khalifa',
#  'Mai bint Mohammed Al Khalifa',
#  'Salman bin Khalifa Al Khalifa',
#  'Hamad Al Kooheji',
#  'Abdullatif Al-Mahmood',
#  'Rasheed Mohammed Al Maraj',
#  'Khalid Al Maskati',
#  'Abdulhussain bin Ali Mirza',
#  'Mohammed Al-Buainain',
#  'Mohammed bin Khalifa bin Ahmed',
#  'Mohammed bin Khalifa bin Ali Al Khalifa',
#  'Abdulrahman al-Nuaimi',
#  'Ammar Qambar',
#  'Isa Qassim',
#  'Abdulla Hassan Saif',
#  'Ali bin Saleh Al Saleh',
#  'Ahmed Al-Salloum',
#  'Salman bin Hamad Al Khalifa',
#  'Abdul Motaleb',
#  'Abdus Salam (Chattogram politician)',
#  'Abul Hashim',
#  'Oli Ahad',
#  'Chowdhury Shamsuddin Ahmed',
#  'Farid Ahmed',
#  'Muzaffar Ahmed (NAP politician)',
#  'AKM Hafizuddin',
#  'Mohammad Manjur Alam',
#  'M Hossain Ali',
#  'Aminul Islam Rabel',
#  'Mohammad A. Arafat',
#  'Ashab Uddin Ahmad',
#  'Shafiqur Rahman Badsha',
#  'Selina Banu',
#  'Nurul Huq Bhuiyan',
#  'Birendra Kishore Roaza',
#  'Bishnu Chattopadhyay',
#  'AKM Fazlul Kabir Chowdhury',
#  'Aminul Islam Chowdhury',
#  'Anwarul Karim Chowdhury',
#  'Moinuddin Ahmed Chowdhury',
#  'Sarwar Jan Chowdhury',
#  'Shahinur Pasha Chowdhury',
#  'Yusuf Ali Chowdhury',
#  'Haji Mohammad Danesh',
#  'Pulin De',
#  'James Leo Ferguson',
#  'Abdul Halim Ghaznavi',
#  'Debendra Nath Ghosh',
#  'Ranesh Das Gupta',
#  'AKM Fazlul Haque (Jatiya Party politician)',
#  'Syed Najmuddin Hashim',
#  'M. Anwar Hossain',
#  'Nozir Hossain',
#  'Husam Uddin Chowdhury Fultali',
#  'Syed Muhammad Ibrahim',
#  'Abul Kashem',
#  'Abul Kashem Khan',
#  'Hatem Ali Khan',
#  'Muhammad Hamidullah Khan',
#  'Yar Mohammad Khan',
#  'Kazi Abdus Shahid Lal',
#  'Jyotirindra Bodhipriya Larma',
#  'Shamima Harun Lubna',
#  'Manik Lal Ray',
#  'Manjurul Imam',
#  'Mushrefa Mishu',
#  'Moin Uddin (politician)',
#  'Fazlul Haque Montu',
#  'Mujahidul Islam Selim',
#  'Mujibur Rahman (Chattogram politician)',
#  'Shafiul Alam Chowdhury Nadel',
#  'SM Nuruzzaman',
#  'Shamsul Huda Panchbagi',
#  'Muhammad Bayazeed Khan Panni',
#  'Ferdous Ahmed Qureshi',
#  'Asheq Ullah Rafiq',
#  'Abdur Rahim (scholar)',
#  'Habibar Rahman',
#  'M. M. Rahmatullah',
#  'Golam Maula Rony',
#  'Devasish Roy',
#  'Mahmudul Haque Sayem',
#  'Maulana Shakhawat',
#  'Abul Kalam Shamsuddin',
#  'Badruddoza Ahmed Shuja',
#  'Sourendra Nath Chakraborty',
#  'Mohammad Sultan',
#  'Syed Sayedul Haque Suman',
#  'Mohammad Toaha',
#  'Badruddin Umar',
#  'Zahidunnabi Dewan Shamim',
#  'Mohammad Zillur Rahman',
#  'Elliott Belgrave',
#  'Chad Blackman',
#  'Santia Bradshaw',
#  'Sonia Browne',
#  'Michael A. Carrington',
#  'William Fondleroy Duguid',
#  'Reginald Farley',
#  'Adrian Forde',
#  'Cynthia Y. Forde',
#  'Ian Gooding-Edghill',
#  'Damien K. A. Griffith',
#  'Crystal Haynes',
#  'Philip St. Hill',
#  'Kirk Matthew Humphrey',
#  'Davidson Ishmael',
#  'Colin Everett Jordan',
#  'John Andrew King',
#  'Shantal Munro-Knight',
#  'Glyne Murray',
#  "Charles Duncan O'Neal",
#  'Samuel Jackman Prescod',
#  'Shanika Roberts-Odle',
#  'Ryan Straughn',
#  'Dwight Sutherland',
#  'Kerrie Symmonds',
#  'Yury Ambrazevich',
#  'Aliaksandr Azarau',
#  'Lyavon Barshchewski',
#  'Siarhei Cherachen',
#  'Zmitser Dashkevich',
#  'Siamion Domash',
#  'Tsimafei Dranchuk',
#  'Alaksandar Dubko',
#  'Gennady Grushevoy',
#  'Moshe Gutman',
#  'Uładzimir Hančaryk',
#  'Tamaš Hryb',
#  'Anatoĺ Kalinin',
#  'Voĺha Karač',
#  'Uładzisłau Kazłouski',
#  'Tadeusz Kościuszko',
#  'Ivan Kubrakov',
#  'Vladimir Kumets',
#  'Valery Levaneuski',
#  'Uladzimir Mackievič',
#  'V. L. Mukha',
#  'Jan Pazniak',
#  'Aleksandr Potupa',
#  'Pyotr Prakapovich',
#  'Alexander Radkov',
#  'Symon Rak-Michajłoŭski',
#  'Vladimir Rusakevich',
#  'Ihar Rynkevich',
#  'Valery Sakhashchyk',
#  'Dominik Semashko',
#  'Aliaksandr Shakutsin',
#  'Nikolai Shelyagovich',
#  'Jan Stankievič',
#  'Mikola Statkevich',
#  'Sergei Tikhanovsky',
#  'Aleksandr Turchin',
#  'Yury Voskresensky',
#  'Edward Woyniłłowicz',
#  'Ivan Yermachenka',
#  'Manuel Abramowicz',
#  'Rudy Aernoudt',
#  'Herman Baltia',
#  'Jan Béghin',
#  'Frank Beke',
#  'Gustave Boël',
#  'Pol Clovis Boël',
#  'Antoine Brun',
#  'Fernand Cocq',
#  'Émile Coulonvaux',
#  'Auguste Couvreur',
#  'Nico Cué',
#  'Pierre David (mayor)',
#  'Marcel de Baer',
#  'August De Boodt',
#  'Norbert De Cuyper',
#  'Dirk De fauw',
#  'René De Feyter',
#  'François-Philippe de Haussy',
#  'Victor de Laveleye',
#  'Édouard Descamps',
#  'José Desmarets',
#  'Émile van Dievoet',
#  'Marc Drumaux',
#  'Jos Dupré',
#  'Françoise Dupuis',
#  'Veerle Geerinckx',
#  "Eugène Goblet d'Alviella",
#  'Julien Goekint',
#  'Jean-Pierre Grafé',
#  'Jacques Grippa',
#  'Guy Hance',
#  'Joris Helleputte',
#  'Lucienne Herman-Michielsens',
#  'Jules Hiernaux',
#  'Julius Hoste Jr.',
#  'Norbert Hougardy',
#  'Joseph Houssa',
#  'Vincent Houssiau',
#  'Pierre Van Humbeeck',
#  'Dorah Ilunga',
#  'Pierre Imperiali',
#  'Jean-François Istasse',
#  'Milou Jeunehomme',
#  'Georges Kaeckenbeeck',
#  'André Kempinaire',
#  'Ahmet Koç (politician)',
#  'Willy Kuijpers',
#  'Rachid Madrane',
#  'Luc Michel',
#  'Fientje Moerman',
#  'André Molitor',
#  'Jean Pede',
#  'Pierre Emmanuel Félix Chazal',
#  'Jean-Marie Piret',
#  'André-Eugène Pirson',
#  'Marjet Van Puymbroeck',
#  'Jean Richardot the Younger',
#  'Gustave Rolin-Jaequemyns',
#  'Hippolyte Rolin',
#  'Father Samuel',
#  'Louis-Joseph Seutin',
#  'Alfons Siffer',
#  'Cyrille Tahay',
#  'Jacques Timmermans',
#  'Robert Urbain',
#  'Adolphe Van Glabbeke',
#  'Gaëtan Van Goidsenhoven',
#  'Jacques Van Gompel',
#  'Marcel Van Langenhove (referee)',
#  'Johan Verbeke',
#  'Yvan Verougstraete',
#  'Lodewijk Verreycken',
#  'Louis Waltniel',
#  'Yves de Wasseige',
#  'Roger Windels',
#  'Jacques van Ypersele de Strihou',
#  'Nemencio Acosta',
#  'Basilio Ah',
#  'Beverly Castillo',
#  'Charles Bartlett Hyde',
#  'Glenn Godfrey',
#  'Alexander Albert Hunter',
#  'Elfreda Reyes',
#  'Bert Tucker',
#  'Woldrich Harrison Courtenay',
#  'Arnauld Antoine Akodjènou',
#  'Jules-Armand Aniambossou',
#  'Francis Covi',
#  'Sefou Fagbohoun',
#  'Louis Hunkanrin',
#  'Louis Ignacio-Pinto',
#  'Arouna Mama',
#  'D. N. Dhungyel',
#  'Dorjee Wangmo',
#  'Ugyen Dorji (DNT politician)',
#  'Zangley Dukpa',
#  'Dupthob',
#  'Choki Gyeltshen',
#  'Sherub Gyeltshen',
#  'Choida Jamtsho',
#  'Rinzin Jamtsho',
#  'Shingkhar Lam',
#  'Tshewang Lhamo',
#  'Kuenga Loday',
#  'Dorji Namgyal',
#  'Jigme Namgyal (Bhutan)',
#  'Kunzang C. Namgyel',
#  'Wangdi Norbu',
#  'Pema Chewang',
#  'Pema Gyamtsho',
#  'Kinga Penjor',
#  'Yeshey Penjor',
#  'Thakur S. Powdyel',
#  'Jai Bir Rai',
#  'Karma Rangdol',
#  'Chogyal Dago Rigdzin',
#  'Loknath Sharma',
#  'Tenzin (politician)',
#  'Sonam Tobgye',
#  'Dorji Tshering',
#  'Kinga Tshering',
#  'Namgay Tshering',
#  'Ugyen Tshering',
#  'Jigme Wangchuk',
#  'Lhatu Wangchuk',
#  'Khandu Wangchuk',
#  'Norbu Wangchuk',
#  'Tshering Wangchuk',
#  'Karma Donnen Wangdi',
#  'Tshencho Wangdi',
#  'Ugyen Wangdi',
#  'Dechen Wangmo (politician)',
#  'Dechen Zangmo',
#  'Neten Zangmo',
#  'Nidup Zangpo',
#  'Yeshey Zimba',
#  'Botche Candé',
#  'Juliano Fernandes',
#  'Teodora Inácia Gomes',
#  'Desejado Lima da Costa',
#  'Aristide Menezes',
#  'Florentino Mendes Pereira',
#  'Carmelita Pires',
#  'Agnelo Regalla',
#  'Nataniel Aguirre',
#  'Francisco Argandoña',
#  'Atanasio de Urioste Velasco',
#  'Isaac Ávalos',
#  'Augusto Céspedes',
#  'Adolfo Chávez',
#  'Chi Hyun Chung',
#  'Pantaleón Dalence',
#  'Rafael Peña',
#  'Marcelo Elío',
#  'Marcial Fabricano',
#  'Fernando Eloy Guachalla',
#  'Toribia Lero Quispe',
#  'Antonio Machaca',
#  'Adolfo Mendoza',
#  'Manuel de Molina Zamudio',
#  'Pedro Domingo Murillo',
#  "Francisco Burdett O'Connor",
#  'Manuel Luis de Oliden',
#  'Simón Iturri Patiño',
#  'Bonifacio Pinedo',
#  'Julio Pinedo',
#  'Gary Prado Salmón',
#  'José Mariano Serrano',
#  'Moisés Torres (politician)',
#  'Fernando Vargas Mosua',
#  'Jaime de Zudáñez',
#  'Kemal Ademović',
#  'Mehmed Alajbegović',
#  'Boško Baškot',
#  'Salko Bukvarević',
#  'Sabina Ćudić',
#  'Dženan Đonlagić',
#  'Edin Forto',
#  'Dževad Galijašević',
#  'Josip Grubeša',
#  'Ankica Gudeljević',
#  'Hakija Hadžić',
#  'Mirsad Hadžikadić',
#  'Sanjin Halimović',
#  'Sevlid Hurtić',
#  'Husein Miljković',
#  'Jasmin Imamović',
#  'Adamir Jerković',
#  'Esed Kadrić',
#  'Mehmed Kapetanović',
#  'Osman Karabegović',
#  'Rusmir Mahmutćehajić',
#  'Amor Mašović',
#  'Božidar Matić',
#  'Dragan Mektić',
#  'Ademaga Mešić',
#  'Jelka Miličević',
#  'Abdulah Mutapčić',
#  'Abdulah Nakaš',
#  'Damir Nikšić',
#  'Ismet Popovac',
#  'Hakija Pozderac',
#  'Hamdija Pozderac',
#  'Nurija Pozderac',
#  'Đuro Pucar',
#  'Svetozar Pudarić',
#  'Alen Šeranić',
#  'Uglješa Uzelac',
#  'Nezir Škaljić',
#  'Ibrahim Spahić',
#  'Jelena Trivić',
#  'Milan Uzelac',
#  'Dragan Vikić',
#  'Miloš Vukašinović',
#  'Philip Matante',
#  'Leetile Disang Raditladi',
#  'Patrick van Rensburg',
#  'Tobias de Aguiar',
#  'Medeiros e Albuquerque',
#  'Léo de Almeida Neves',
#  'Antônio Pinto Chichorro da Gama',
#  'Cipriano Barata',
#  'Jader Barbalho Filho',
#  'Irani Barbosa',
#  'Djalma Bastos de Morais',
#  'Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan',
#  'Natália Bastos Bonavides',
#  'Marcos Braz',
#  'Amador Bueno',
#  'Maurício Campos de Medeiros',
#  'Marcelo Cecé',
#  'Izolda Cela',
#  'Margarete Coelho',
#  'Paulo Corrêa',
#  'Miguel Couto',
#  'João Cunha (politician)',
#  ...]

# %% [markdown]
# # Step 1
# API call from the document provided in Homework link - Data Extraction and Transformation
# For the below chunk of code i am using the API function provided for the homework and extracting the views data for desktop, mobile-app and mobile web. Once extraction is done I will be saving the output as JSON files.

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<anurag96@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# This is just a list of English Wikipedia article titles that we can use for example requests
ARTICLE_TITLES = politicians

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    
    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
pol_info = {} #blank dictionary to store article and latest revision id

# %%
missing_rev_ids = []  # List to capture articles missing 'lastrevid'

# %%
from tqdm import tqdm
import time

for i in tqdm(politicians, desc="Processing articles"):
    time.sleep(0.01)
    info = request_pageinfo_per_article(i)
    for page_id in info['query']['pages']:
        page_data = info['query']['pages'][page_id]
        
        # Check if 'pagelanguage' is not English
        if page_data.get('pagelanguage') != 'en':
            print(f"Article {page_data['title']} is not in English")
        
        # Check if 'lastrevid' exists, otherwise add to missing list
        if 'lastrevid' in page_data:
            pol_info[i] = page_data['lastrevid']
        else:
            missing_rev_ids.append(page_data['title'])
# Out:
# Processing articles: 100%|██████████████████| 7155/7155 [34:04<00:00,  3.50it/s]

# %%
missing_rev_ids
# Out:
# ['Barbara Eibinger-Miedl',
#  'Mehrali Gasimov',
#  'Kyaw Myint',
#  'André Ngongang Ouandji',
#  'Tomás Pimentel',
#  'Richard Sumah',
#  "Segun ''Aeroland'' Adewale",
#  'Bashir Bililiqo']

# %% [markdown]
# Thus 8 articles are missing Rev IDs.

# %% [markdown]
# **I also noticed that few of the articles do not correspond to politicans i.e they had other professions like 'David Henríquez (footballer, born 1977)'. I could not manually go through each of the articles to exclude them, but the articles which had a paranthesis citing their profession, I excluded the ones except the items in list "exclude_keywords".**

# %%
#professions to exclude from removal
exclude_keywords = [
    'politician', 'civil servant', 'minister', 'mayor', 'President', 
    'general', 'councilor', 'ambassador', 'government', 'diplomat', 'activist', 'political', 'Bhutan'
]

# %%
#using regex to also exclude professions having a year interval in their paranthesis
import re
year_pattern = re.compile(r'\(\d{4}–\d{4}\)')

# %%
#getting those articles which are potentially not politicians
special_cases_articles = [
    article for article in pol_info.keys()
    if '(' in article and ')' in article 
    and not any(keyword.lower() in article.lower() for keyword in exclude_keywords)
    and not year_pattern.search(article)
]

# %%
#removing those articles found in special cases from analysis
for article in special_cases_articles:
    pol_info.pop(article, None)

# %% [markdown]
# # Step 2
# Requesting ORES scores through LiftWing ML Service API - Getting Article Quality Predictions

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{email_address}>, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "anurag96@uw.edu",         # your email address should go here
    'access_token'  : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....lzxrcKKUDdRPv7pF_EkJYONfHYXqYCuzdWO7_C3yNUuki7uNJDU2rfhVfTXsP7Doa0hLYaEW5n_mecVRzYYd3DBmYulvncBodVpMx86ynw6gmJDRkgT-1BlgFoOPgh0Nb0CHEJRdXZwvicuoLt6P036SRNUD9SLGrOzQx6u8TgsNIh9qbDK3q7fRMzZUQ7xO601UJ3ZHjFckhNL23zuMlyXU0EZDi8v5ecgFjRL2W6X_Eu5hqncAkxmv9z8f7euXzhSDw5rWY_eADZ8Vw0xEo8TgmYbT11QqEfLGo8wuRn1V5946wWoy-KcscAediermHLUcIHML-Wm8A6m6G87xDVXEm6DD3cJTeDGgpd60aByPxDlP5KSg86-l2gk4TiHYU-cPueHsLSGjnOo7OHQHiUECQWU0GU3Yo8lP_jXd0dezdiMbL4jMPHmOPx2rP1wQdu0lTeVhY4cpizfBK11lx78IFvV5vAN3epFdLdrTNdRjb-YILTjnzsRg7IHpzsYmRU66lMKs3Ue-h1rIeRSPg1dOoGgqIQsN2lxTWgapbt1MDP9wWQtPoTweJawvelXUBkVb8BGopUuW29K3Xfn2LVrMNEscTX2HpJ5V6XD5R_Fkrh06Pp4-2cJQRCVBUPi2WqOcM4RglO_4I5Qx__ogQviUvz6ZS-v3FaE3egR8iMY"          # the access token you create will need to go here
}

#
#    A dictionary of English Wikipedia article titles (keys) and sample revision IDs that can be used for this ORES scoring example
#
ARTICLE_REVISIONS = pol_info

#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = ""
ACCESS_TOKEN = ""
#

# %%
#   Once you've done the right set up with your Wikimedia account, it should provide you with three different keys, a Client ID,
#   a Client secret, and a Access token.
#
#   In this case I don't want to distribute my keys with the source of the notebook, so I wrote a key manager object that helps
#   track all of my API keys - a username and domain name retrieves the key. The key manager hides the keys on disk separate
#   from the code. A common code idiom to hide API keys will use code to extract the key from an OS environment variable. 
#
#   In the Homework 2 folder you should be able to find a zip file containing the apikeys user module. Install this module
#   into the folder where you keep all of your user modules. This is also the folder that your PYTHONPATH variable points to.
#
#from apikeys.KeyManager import KeyManager
#keyman = KeyManager()

#
#   This is my Wikipedia/Wikimedia username. They suggest you request your keys using your Wikipedia username, so I
#   also stored the API key using my Wikipedia username.
#
#   You should probably use your own username here.
#USERNAME = "Anuragag96"
#key_info = keyman.findRecord(USERNAME,API_ORES_LIFTWING_ENDPOINT)
#ACCESS_TOKEN = key_info[0]['key']
#print(key_info[0]['description'])
#print(ACCESS_TOKEN)
#
#   Note: if you don't want to use the key manager to help manage your API keys, you can specify the values as constants
#   below. Just don't distribute the notebook without removing the constants or you'll be distributing your key too.
#
USERNAME = "Anuragag96"
ACCESS_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....lzxrcKKUDdRPv7pF_EkJYONfHYXqYCuzdWO7_C3yNUuki7uNJDU2rfhVfTXsP7Doa0hLYaEW5n_mecVRzYYd3DBmYulvncBodVpMx86ynw6gmJDRkgT-1BlgFoOPgh0Nb0CHEJRdXZwvicuoLt6P036SRNUD9SLGrOzQx6u8TgsNIh9qbDK3q7fRMzZUQ7xO601UJ3ZHjFckhNL23zuMlyXU0EZDi8v5ecgFjRL2W6X_Eu5hqncAkxmv9z8f7euXzhSDw5rWY_eADZ8Vw0xEo8TgmYbT11QqEfLGo8wuRn1V5946wWoy-KcscAediermHLUcIHML-Wm8A6m6G87xDVXEm6DD3cJTeDGgpd60aByPxDlP5KSg86-l2gk4TiHYU-cPueHsLSGjnOo7OHQHiUECQWU0GU3Yo8lP_jXd0dezdiMbL4jMPHmOPx2rP1wQdu0lTeVhY4cpizfBK11lx78IFvV5vAN3epFdLdrTNdRjb-YILTjnzsRg7IHpzsYmRU66lMKs3Ue-h1rIeRSPg1dOoGgqIQsN2lxTWgapbt1MDP9wWQtPoTweJawvelXUBkVb8BGopUuW29K3Xfn2LVrMNEscTX2HpJ5V6XD5R_Fkrh06Pp4-2cJQRCVBUPi2WqOcM4RglO_4I5Qx__ogQviUvz6ZS-v3FaE3egR8iMY"
#

# %%
#
#   Decode the Wikimedia JWT Access token
#
#   NOTE: This is not required to use LiftWing to request ORES scores. This is just being done to satisfy my curiosity.
#   You might be curious too!
#
import base64

print("Decoding the ACCESS_TOKEN:")
try:
    token_components = ACCESS_TOKEN.split(".")
    if len(token_components) == 3:
        header = json.loads(base64.b64decode(token_components[0]).decode())
        payload = json.loads(base64.b64decode(token_components[1]).decode())
        print("Token Header:",json.dumps(header,indent=4))
        print("Token Payload:",json.dumps(payload,indent=4))
        #print("Token Signature:",token_components[2])
        print("Token Signature: <value_suppressed>")
        #
        #  One should be able to use public/private keys to actually validate that signature - left as an exercise for later
        #
    else:
        print(f"The ACCESS_TOKEN appears to be improperly structured. It should have 3 components and it has {len(token_components)}")
except Exception as ex:
    print(f"Looks like the ACCESS_TOKEN is undefined or an empty value")
    raise(ex)
# Out:
# Decoding the ACCESS_TOKEN:
# Looks like the ACCESS_TOKEN is undefined or an empty value
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[97], line 26
#      24 except Exception as ex:
#      25     print(f"Looks like the ACCESS_TOKEN is undefined or an empty value")
# ---> 26     raise(ex)
#
# Cell In[97], line 14
#      12 if len(token_components) == 3:
#      13     header = json.loads(base64.b64decode(token_components[0]).decode())
# ---> 14     payload = json.loads(base64.b64decode(token_components[1]).decode())
#      15     print("Token Header:",json.dumps(header,indent=4))
#      16     print("Token Payload:",json.dumps(payload,indent=4))
#
# File /opt/anaconda3/lib/python3.12/base64.py:88, in b64decode(s, altchars, validate)
#      86     assert len(altchars) == 2, repr(altchars)
#      87     s = s.translate(bytes.maketrans(altchars, b'+/'))
# ---> 88 return binascii.a2b_base64(s, strict_mode=validate)
#
# Error: Incorrect padding

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
ores_score = {} #blank dictionary to store scores

# %%
no_ores_score = [] #list to get those articles not giving an ores score

# %%
#in actual there are 7035 articles for which the scores were processed
for key, value in tqdm(pol_info.items(), desc="Processing articles"):
    article_title = key
    # Request the ORES score for the article
    score = request_ores_score_per_article(article_revid=ARTICLE_REVISIONS[article_title],
                                           email_address="anurag96@uw.edu",
                                           access_token=ACCESS_TOKEN)
    
    try:
        # Attempt to retrieve the prediction score in a single line
        ores_score[key] = score['enwiki']['scores'][f'{value}']['articlequality']['score']['prediction']
    except KeyError:
        # If any part of the path does not exist, the KeyError will be caught
        no_ores_score.append(key)
# Out:
# Processing articles: 100%|████████████████████| 755/755 [14:49<00:00,  1.18s/it]

# %%
#viewing the ores score
ores_score
# Out:
# {'Majah Ha Adrif': 'Start',
#  'Haroon al-Afghani': 'B',
#  'Tayyab Agha': 'Start',
#  'Khadija Zahra Ahmadi': 'Stub',
#  'Aziza Ahmadyar': 'Start',
#  'Muqadasa Ahmadzai': 'Start',
#  'Mohammad Sarwar Ahmedzai': 'Start',
#  'Amir Muhammad Akhundzada': 'Start',
#  'Nasrullah Baryalai Arsalai': 'Start',
#  'Abdul Rahim Ayoubi': 'Start',
#  'Ismael Balkhi': 'Start',
#  'Abdul Baqi Turkistani': 'Stub',
#  'Mohammad Ghous Bashiri': 'Start',
#  'Jan Baz': 'Stub',
#  'Bashir Ahmad Bezan': 'Start',
#  'Rafiullah Bidar': 'Stub',
#  'Mohammad Siddiq Chakari': 'Stub',
#  'Cheragh Ali Cheragh': 'Start',
#  'Nasir Ahmad Durrani': 'Stub',
#  'Muhammad Hashim Esmatullahi': 'Stub',
#  'Aimal Faizi': 'Stub',
#  'Gajinder Singh Safri': 'Stub',
#  'Sharif Ghalib': 'Start',
#  'Hashmat Ghani Ahmadzai': 'C',
#  'Abdul Ghani Ghani': 'Stub',
#  'Ghulam Ghaus': 'Stub',
#  'Ghulam Muhammad Ghobar': 'Stub',
#  'Sayed Yousuf Halim': 'Stub',
#  'Rangina Hamidi': 'C',
#  'Sayed Zafar Hashemi': 'Start',
#  'Qutbuddin Hilal': 'Start',
#  'Mahboba Hoqomal': 'Stub',
#  'Musa Hotak': 'Start',
#  'Mirza Muhammad Ismail': 'C',
#  'Sayed Jalal': 'Start',
#  'Said Tayeb Jawad': 'C',
#  'Sayed Jalal Karim': 'Start',
#  'Hafizullah Shabaz Khail': 'Start',
#  'Masoud Khalili': 'GA',
#  'Samoud Khan': 'Start',
#  'Baran Khan Kudezai': 'Start',
#  'Azizullah Lodin': 'Start',
#  'Razaq Mamoon': 'Start',
#  'Fazel Ahmed Manawi': 'Start',
#  'Moeen Marastial': 'Start',
#  'Ahmad Wali Massoud': 'Start',
#  'Mohammad Daud Miraki': 'C',
#  'Abdul Sattar Mirzakwal': 'Stub',
#  'Abdul Karim Misaq': 'Stub',
#  'Ali Mohammad (politician)': 'Stub',
#  'Nasruddin Mohseni': 'Start',
#  'Davood Moradian': 'Stub',
#  'Zalmai Mujadidi': 'Start',
#  'Sardar Mohammad Nadir Naeem': 'Stub',
#  'Daoud Naji': 'Start',
#  'Gholam Rabani Nasher': 'Stub',
#  'Ghulam Faroq Nijrabi': 'Stub',
#  'Zabih-U-llah Ghazi Noristani': 'Start',
#  'Mohammed Tahir Omar': 'Stub',
#  'Mohammed Qalamuddin': 'Stub',
#  'Ghulam Mohammad Rigi': 'Stub',
#  'Ghulam Hassan Safi': 'Stub',
#  'Hanifa Safi': 'Stub',
#  'Mohammed Zia Salehi': 'Stub',
#  'Abdul Majid Samim': 'Stub',
#  'Saber Sangar': 'Stub',
#  'Sayed Nasim Mihanparast': 'Stub',
#  'Suhail Shaheen': 'Start',
#  'Fazal Hadi Shinwari': 'GA',
#  'Baktash Siawash': 'Stub',
#  'Hasan Ali Sultani': 'Stub',
#  'Mohammad Hashem Taufiqui': 'Start',
#  'Pacha Gul Wafadar': 'Stub',
#  'Wahidullah Waissi': 'C',
#  'Ahmadullah Wasiq': 'Start',
#  'Gul Ahmmad Yama': 'Start',
#  'Abdul Salam Zaeef': 'GA',
#  'Abdul Zahir (Konar Education Minister)': 'Stub',
#  'Mohammed Zaman': 'Start',
#  'Qari Ziauddin': 'Start',
#  'Abdul Ghafor Zori': 'Stub',
#  'Ali Pasha of Gusinje': 'GA',
#  'Ylli Asllani': 'Start',
#  'Azis Tahir Ajdonati': 'Stub',
#  'Bislim Bajgora': 'C',
#  'Kastriot Berissa': 'Start',
#  'Bardhok Biba': 'C',
#  'Kostandin Boshnjaku': 'C',
#  'Spartak Braho': 'Start',
#  'Safet Butka': 'C',
#  'Uran Butka': 'Start',
#  'Refo Çapari': 'Start',
#  'Neritan Ceka': 'Start',
#  'Hysni Curri': 'Start',
#  'Ibrahim Dalliu': 'Start',
#  'Niazi Demi': 'Stub',
#  'Abdurrahman Dibra': 'Start',
#  'Bujar Dida': 'C',
#  'Ahmed Dino': 'Stub',
#  'Rasih Dino': 'Stub',
#  'Ferhat Bey Draga': 'C',
#  'Nexhip Draga': 'GA',
#  'Aqif Pasha Elbasani': 'GA',
#  'Abas Ermenji': 'Start',
#  'Qamil Musa Haxhi Feza': 'Stub',
#  'Themistokli Gërmenji': 'C',
#  'Sabri Godo': 'C',
#  'Mihal Grameno': 'C',
#  'Aćif Hadžiahmetović': 'GA',
#  'High Council of Regency': 'C',
#  'Kurt Agë Kadiu': 'Stub',
#  'Mehmed Kalakula': 'Stub',
#  'Alfred Karamuço': 'Stub',
#  'Ibrahim Karbunara': 'C',
#  'Ali Këlcyra': 'Start',
#  'Bajram Kelmendi': 'Start',
#  'Kristo Kirka': 'C',
#  'Elez Koçi': 'Start',
#  'Xhelal Koprëncka': 'Stub',
#  'Kryeziu family': 'Start',
#  'Artur Kuko': 'Stub',
#  'Xhavid Leskoviku': 'Start',
#  'Sabit Lulo': 'Stub',
#  'Gjon Markagjoni': 'C',
#  'Tefik Mborja': 'Start',
#  'Hysni Milloshi': 'Start',
#  'Musa Qazimi': 'GA',
#  'Mustafa Ndroqi': 'Stub',
#  'Behxhet Nepravishta': 'Stub',
#  'Adrian Neritani': 'Start',
#  'Sali Nivica': 'Start',
#  'Thoma Orologa': 'Start',
#  'Bedri Pejani': 'C',
#  'Kadri Prishtina': 'Start',
#  'Ymer Prizreni': 'Start',
#  'Avni Rustemi': 'Start',
#  'Chatin Sarachi': 'C',
#  'Nebi Sefa': 'Stub',
#  'Eduard Shalsi': 'Start',
#  'Ylli Vesel Shehu': 'Stub',
#  'Athanas Shundi': 'C',
#  'Xhelal Sveçla': 'Start',
#  'Mehmet Tahsini': 'Stub',
#  'Ibrahim Temo': 'GA',
#  'Afrim Tole': 'Stub',
#  'Syreja Vlora': 'Start',
#  'Visarion Xhuvani': 'C',
#  'Visar Ymeri': 'Stub',
#  'Abdyl Ypi': 'Stub',
#  'Xhezair Zaganjori': 'Start',
#  'Menduh Zavalani': 'FA',
#  'Abdelkader Zoukh': 'Start',
#  'Chaâbane Aït Abderrahim': 'Start',
#  'Ali Aoun': 'Start',
#  'Basma Azouar': 'Stub',
#  'Mohamed Seghir Babes': 'Stub',
#  'Noureddine Bahbouh': 'Stub',
#  'Lamine Bechichi': 'Stub',
#  'Aïssa Bekkai': 'Stub',
#  'Abdelhakim Belabed': 'Start',
#  'Mohamed Tarek Belaribi': 'Start',
#  'Kamel Beldjoud': 'Stub',
#  'Aboubakr Belkaid': 'Start',
#  'Youcef Belmehdi': 'Stub',
#  'Mohamed Cherif Belmihoub': 'Start',
#  'Mohamed Belouizdad': 'Start',
#  'Benaouda Hadj Hacène Bachterzi': 'Stub',
#  'Souad Bendjaballah': 'Stub',
#  'Abdelkrim Benmbarek': 'Stub',
#  'Mohamed Bensalam': 'Stub',
#  'Fayçal Bentaleb': 'Stub',
#  'Ahmed Bidani': 'Start',
#  'Kamel Bidari': 'GA',
#  'Rachid Bladehane': 'Stub',
#  'Saïd Boualam': 'Start',
#  'Rabah Bouaziz': 'Start',
#  'Abdeslam Bouchouareb': 'Stub',
#  'Ibrahim Boughali': 'Stub',
#  'Yahia Boukhari': 'Stub',
#  'Mohamed Bouslimani': 'Stub',
#  'Foued Chehat': 'Stub',
#  'Hamza Al Sid Cheikh': 'Stub',
#  'Hocine Cherhabil': 'Stub',
#  'Abderrahmane Meziane Chérif': 'Start',
#  'Saïd Chibane': 'Stub',
#  'Brahim Chibout': 'Stub',
#  'Youcef Chorfa': 'Start',
#  'Fazia Dahleb': 'Stub',
#  'Taha Derbal': 'Stub',
#  'Nassim Diafat': 'Stub',
#  'Mokhtar Didouche': 'Start',
#  'Bouras Djamel': 'Stub',
#  'Fatiha Serour': 'Start',
#  'Ahmed Hamiani': 'Stub',
#  'Nadir Kassab': 'Stub',
#  'Brahim Djamel Kassali': 'Start',
#  'Kaoutar Krikou': 'Stub',
#  'Sassi Lamouri': 'Stub',
#  'Mohamed Maghlaoui': 'Stub',
#  'Amar Makhloufi': 'Stub',
#  'Yassine Merabi': 'Stub',
#  'Brahim Merad': 'Start',
#  'Bachir Messaitfa': 'Stub',
#  'Azzedine Mihoubi': 'Start',
#  'Mohamed Ali Boughazi': 'Start',
#  'Amar Mohammedi': 'Start',
#  'Samia Moualfi': 'Stub',
#  'Soraya Mouloudji': 'Stub',
#  'Yacine Oualid': 'Stub',
#  'Cherif Rahmani': 'Stub',
#  'Lakhdar Rakhroukh': 'Stub',
#  'Laid Rebiga': 'Stub',
#  'Kamel Rezig': 'Stub',
#  'Salim Saadi': 'Stub',
#  'Abdelhak Saihi': 'Stub',
#  'Hichem Sofiane Salaouatchi': 'Stub',
#  'Naima Salhi': 'Stub',
#  'Abderezak Sebgag': 'Stub',
#  'Abderrachid Tabbi': 'Stub',
#  'Karim Bibi Triki': 'Start',
#  'Layachi Yaker': 'Start',
#  'Ahmed Zeghdar': 'Stub',
#  'Adão Francisco Correia de Almeida': 'Stub',
#  'Ana Paula Chantre Luna de Carvalho': 'Stub',
#  'Alexandre Sebastião André': 'Stub',
#  'Paulino Baptista': 'Start',
#  'Bernarda Gonçalves Martins': 'Stub',
#  'João Baptista Borges': 'C',
#  'Carolina Cerqueira': 'C',
#  'Arlete Chimbinda': 'Start',
#  'Kafundanga Chingunji': 'Stub',
#  'Jeremias Chitunda': 'Start',
#  'Abel Chivukuvuku': 'Start',
#  'Fiel Domingos Constantino': 'Stub',
#  'Adalberto Costa Júnior': 'Stub',
#  'Adjany Costa': 'Start',
#  'Álvaro Arnaldo Craveiro': 'Stub',
#  'Raul Danda': 'Stub',
#  'Diamantino Pedro Azevedo': 'Stub',
#  'Faustina Fernandes Inglês de Almeida Alves': 'Stub',
#  'Abraão Gourgel': 'Stub',
#  'Jofre Van-Dúnem Júnior': 'Stub',
#  'José Carvalho da Rocha': 'Stub',
#  'José Luis de Matos': 'Stub',
#  'Kambamba Kulaxingo': 'Stub',
#  'Jesus Faria Maiato': 'Stub',
#  'Manuel Neto da Costa': 'Stub',
#  'Manuel Tavares de Almeida': 'Stub',
#  'Marcos Alexandre Nhunga': 'Stub',
#  'Maria Cândida Pereira Teixeira': 'Stub',
#  'Maria do Rosário Teixeira de Alva Sequeira Bragança Sambo': 'Stub',
#  'David Mendes': 'Stub',
#  'Saíde Mingas': 'GA',
#  'Fernando Faustino Muteka': 'Stub',
#  'Pedro Mutinde': 'Start',
#  'José Ndele': 'Stub',
#  'Ana Paula Sacramento Neto': 'Stub',
#  'Daniel Ntongi-Nzinga': 'Stub',
#  'Paula Cristina Francisco Coelho': 'Stub',
#  'Pedro Pedalé': 'Stub',
#  'Elias Salupeto Pena': 'Start',
#  'Johnny Eduardo Pinnock': 'Stub',
#  'Santana André Pitra': 'Stub',
#  'Francisco Manuel Monteiro de Queiróz': 'Stub',
#  'José Aníbal Lopes Rocha': 'Stub',
#  'José da Rocha': 'Stub',
#  'Rosa Luís de Sousa Micolo': 'Stub',
#  'Luís Gomes Sambo': 'Start',
#  'Branca Manuel Espirito Santo': 'Stub',
#  'João Ernesto dos Santos': 'Stub',
#  'José Filomeno dos Santos': 'C',
#  'Jonas Savimbi': 'GA',
#  'Pinda Simão': 'Stub',
#  'Manuel Bernardo de Sousa': 'Stub',
#  'Augusto da Silva Tomás': 'Stub',
#  'José Jacinto Van-Dúnem': 'C',
#  'José Vieira Dias Van-Dúnem': 'Stub',
#  'Luzia Inglês Van-Dúnem': 'Start',
#  'Manuel Vicente': 'C',
#  'Mfulupinga Nlando Victor': 'Start',
#  'Clement Antonio': 'Stub',
#  'Randolph Beazer': 'Stub',
#  'Studiation Brown': 'Stub',
#  'Alex Browne (politician)': 'Stub',
#  "Colin O'Neil Browne": 'Stub',
#  'James Carlisle': 'C',
#  'Gail Christian': 'Start',
#  'Mackenzie Frank': 'Stub',
#  'Osbert Richard Frederick': 'Start',
#  'Caleb Gardiner': 'Stub',
#  'Shenella Mary Shadida Govia': 'Stub',
#  'William Haynes-Smith': 'C',
#  'Tim Hector': 'C',
#  'Cheryl Mary Clare Hurst': 'Stub',
#  'Wilfred Jacobs': 'Stub',
#  'Kiz Johnson': 'Stub',
#  'Fabian Jones': 'Stub',
#  'Johnathan Joseph (politician)': 'Stub',
#  'Kelvin Simon': 'Start',
#  'Harold Lovell': 'Start',
#  'Edmond Mansoor': 'Start',
#  'David Massiah': 'Stub',
#  'Joanne Massiah': 'Stub',
#  'Dwayne George': 'Stub',
#  'Knacyntar Nedd': 'Stub',
#  'Melford Nicholas': 'Start',
#  'Shawn Nicholas': 'Stub',
#  'Bernard Percival': 'Stub',
#  'Jamale Pringle': 'Stub',
#  'Philip Shoul': 'Stub',
#  'Rawdon Turner': 'Stub',
#  'Alincia Williams-Grant': 'Start',
#  'Juan Alemann': 'Stub',
#  'Germán Alfaro': 'C',
#  'Joaquín Samuel de Anchorena': 'Start',
#  'Juan Agustín Augier': 'Stub',
#  'Uladislao Augier': 'Stub',
#  'Marco Aurelio Avellaneda': 'Start',
#  'Joaquín Belgrano': 'Start',
#  'Antonio Bermejo': 'Start',
#  'Antonio Beruti': 'Start',
#  'Héctor Bidonde': 'Start',
#  'Silvano Bores': 'Stub',
#  'Exequiel Bustillo': 'Start',
#  'Mario Cafiero': 'Stub',
#  'Alberto Manuel Campos': 'Start',
#  'Alejo Castex': 'C',
#  'Dámaso Centeno': 'Stub',
#  'Rossana Chahla': 'C',
#  'Lázaro Chiappe': 'Stub',
#  'Carlos Corach': 'Stub',
#  'Jorge Coscia': 'Stub',
#  'Carlos de la Rosa': 'Stub',
#  'Juan Carlos Del Bello': 'Stub',
#  'Luis L. Domínguez': 'C',
#  'Máximo Etchecopar': 'Start',
#  'Héctor Toty Flores': 'Stub',
#  'Guillermo Francos': 'Start',
#  'Juan Fugl': 'Stub',
#  'Santiago Gallo': 'Start',
#  'Manuel José García': 'Stub',
#  'Juan José Gómez Centurión': 'Stub',
#  'Luis Carlos Gómez Centurión': 'Stub',
#  'Martín Guzmán': 'C',
#  'Federico Helguera': 'Start',
#  'Fernando Iglesias (Argentine politician)': 'C',
#  'Ricardo Kennedy': 'Stub',
#  'Carlos Kunkel': 'Stub',
#  'Norberto La Porta': 'Stub',
#  'Andrés Larroque': 'Start',
#  'Julián de Leyva': 'Stub',
#  'Mónica López (politician)': 'Stub',
#  'Lucio Victorio Mansilla': 'Start',
#  'Nicolás Massot': 'Start',
#  'Martín Menem': 'Start',
#  'Juan Mignaburu': 'Stub',
#  'Guillermo Montenegro': 'Stub',
#  'Mariano Moreno': 'FA',
#  'Marcelo Muniagurria': 'Start',
#  'Fernando Nadra': 'C',
#  'Rómulo Sebastián Naón': 'Start',
#  "Santiago G. O'Farrell": 'Start',
#  'Alfredo Olmedo': 'Stub',
#  'Miguel Ángel Pesce': 'Start',
#  'Carlos Petroni': 'C',
#  'Alejo Peyret': 'B',
#  'Aldo Pignanelli': 'Stub',
#  'Abel Posse': 'C',
#  'Enrique S. Quintana': 'Start',
#  'Amán Rawson': 'Start',
#  'Martín Sabbatella': 'C',
#  'Juan Pablo Schiavi': 'C',
#  'Héctor Tizón': 'Start',
#  'Claudio Uberti': 'C',
#  'Arístides Villanueva': 'Start',
#  'Jorge Yoma': 'C',
#  'Ashot Arsenyan': 'C',
#  'Vigen Chitechyan': 'Stub',
#  'Hayk Chobanyan': 'Start',
#  'Gurgen Egiazaryan': 'Start',
#  'Parunak Ferukhan': 'Stub',
#  'Gevorg Ghazaryan (politician)': 'Stub',
#  'Andrias Ghukasyan': 'Start',
#  'Aram Grigoryan (politician)': 'Start',
#  'Vahagn Hovakimyan': 'Start',
#  'Tigran Karapetyan': 'Start',
#  'Tigran Khzmalyan': 'C',
#  'Mikayel Kotanyan': 'Start',
#  'Hrant Maloyan': 'C',
#  'Khachatur Malumian': 'C',
#  'Aram Manukyan': 'Start',
#  'Gevorg Melik-Karagyozyan': 'Stub',
#  'Vahan Minakhoryan': 'Stub',
#  'Ruben Miroyan': 'Start',
#  'Ruben Mirzakhanyan': 'Start',
#  'Badal Muradyan': 'Start',
#  'Narine Tukhikyan': 'Start',
#  'Gabriel Noradoungian': 'C',
#  'Israel Ori': 'Start',
#  'Paul Paul': 'Start',
#  'Garo Paylan': 'C',
#  'Genrikh Poghosyan': 'Start',
#  'Ishkhan Saghatelyan': 'GA',
#  'Martiros Sarukhanyan': 'Stub',
#  'Vartkes Serengülian': 'Start',
#  'Suren Shadunts': 'Start',
#  'Ohannes Tchekidjian': 'Start',
#  'Hrayr Tovmasyan': 'Stub',
#  'Usub Bek Temuryan': 'Stub',
#  'Kegham Vanigian': 'Start',
#  'Serop Zakaryan': 'Stub',
#  'Alfons Adam': 'Start',
#  'Ingo Appelt': 'Stub',
#  'Maximilian Anton Karl, Count Baillet de Latour': 'Start',
#  'Heinrich Alfred Barb': 'Start',
#  'Leopold Berchtold': 'C',
#  'Joseph Buttinger': 'Start',
#  'Prince Carl of Solms-Braunfels': 'C',
#  'Count Václav Antonín Chotek of Chotkov and Vojnín': 'Start',
#  "Citizens' Ministry": 'C',
#  'Richard von Coudenhove-Kalergi': 'C',
#  'Franz Dinghofer': 'GA',
#  'George Abraham von Dyhrn': 'Stub',
#  'Eduard von Grebmer zu Wolfsthurn': 'Start',
#  'Hans Ferlitsch': 'Stub',
#  'Friedhelm Frischenschlager': 'Start',
#  'Walter Guggenberger': 'Start',
#  'Ulrich Habsburg-Lothringen': 'Start',
#  'Ernst Hampel (politician)': 'Stub',
#  'Hans Peter Haselsteiner': 'Start',
#  'Friedrich Wilhelm von Haugwitz': 'C',
#  'Eduard Hedvicek': 'Stub',
#  'Hermann Stern': 'C',
#  'Jürgen Himmelbauer': 'Stub',
#  'Anton Hofer': 'Start',
#  'Andreas Hörtnagl': 'Stub',
#  'Franz Jetzinger': 'Start',
#  'Konstantin Jireček': 'C',
#  'Hugo Jury': 'C',
#  'Joseph Kenner': 'Start',
#  'Theodor Kery': 'Stub',
#  'Michael Killisch-Horn': 'Stub',
#  'Sophia Kircher': 'Stub',
#  'Hubert Klausner': 'Start',
#  'Martin Kocher': 'Stub',
#  'Józef Kożdoń': 'C',
#  'Gottfried von Kühnelt-Leddihn': 'Start',
#  'Franz Leitner (politician)': 'Stub',
#  'Elmar Lichtenegger': 'Start',
#  'Reinhold Lopatka': 'Stub',
#  'Karl Lütgendorf': 'Stub',
#  'Jürgen Mandl': 'Stub',
#  'Renate Mann': 'Stub',
#  'Ferdinand Mannlicher': 'C',
#  'Christoph Matznetter': 'Start',
#  'Johann Gregor Memhardt': 'Stub',
#  'Franz Moroder': 'C',
#  'Heinz Nittel': 'Stub',
#  'Heidemaria Onodi': 'Start',
#  'Brigitta Pallauf': 'Start',
#  'Wladimir von Pawlowski': 'Stub',
#  'Johann Anton von Pergen': 'C',
#  'Gerhard Pfanzelter': 'Start',
#  'Walter Pfrimer': 'C',
#  'Leopold Poetsch': 'Start',
#  'Thomas Prinzhorn': 'C',
#  'Gregor Razumovsky (activist)': 'C',
#  'Horst Rosenkranz': 'Start',
#  'Emil Sax': 'Start',
#  'Peter Schieder': 'Start',
#  'Karl Schmitzer': 'Stub',
#  'Sonja Zwazl': 'Start',
#  'Georg Adam, Prince of Starhemberg': 'C',
#  'Gundaker Thomas Starhemberg': 'Start',
#  'Josef Staribacher': 'Stub',
#  'Peter Strasser (politician)': 'Start',
#  'Julius Tandler': 'Start',
#  'Leopold, Count von Thun und Hohenstein': 'C',
#  'Karl Freiherr von Vogelsang': 'Start',
#  'Anton von Winzor': 'Stub',
#  'Gisela Wurm': 'Stub',
#  'Alexander Zach': 'Stub',
#  'Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau': 'Start',
#  'Karl von Zinzendorf': 'Start',
#  'Muzamil Abdullayev': 'Stub',
#  'Leyla Abdullayeva': 'Start',
#  'Elchin Afandiyev': 'Start',
#  'Fazail Agamali': 'C',
#  'Aliabbas Salahzade': 'Start',
#  'Enver Alikhanov': 'Stub',
#  'Tarlan Aliyarbayov': 'GA',
#  'Dilara Aliyeva': 'Start',
#  'Araz Alizadeh': 'Stub',
#  'Ali Asadov': 'C',
#  'Ashraf Bey Taghiyev': 'Start',
#  'Chimnaz Aslanova': 'Start',
#  'Akram Aylisli': 'C',
#  'Sahil Babayev': 'C',
#  'Huseyngulu Baghirov': 'Start',
#  'Bakhish bey Rustambeyov': 'Start',
#  'Alovsat Bakhshiyev': 'Start',
#  'Mirgasim Cheshmazer': 'Start',
#  'Vilayat Eyvazov': 'Start',
#  'Abdurrahman Fatalibeyli': 'C',
#  'Fazail Ibrahimli': 'Start',
#  'Afshan Gadimbeyova': 'Start',
#  'Garib Karimoğlu': 'Start',
#  'Gudrat Gasanguliev': 'Start',
#  'Solomon Grobshtein': 'Stub',
#  'Teymur Guliyev': 'Stub',
#  'Mammad Gurbanov': 'Start',
#  'Musa Hacigasimov': 'Stub',
#  'Asaf Hajiyev': 'C',
#  'Haji Molla Ahmad Nuruzade': 'GA',
#  'Farhad Hajiyev': 'Start',
#  'Hasan Majidov': 'Start',
#  'Hasan Hasanli': 'Start',
#  'Jamil Hasanli': 'C',
#  'Ali M. Hasanov': 'C',
#  'Zakir Hasanov': 'C',
#  'Ali Huseynli': 'Start',
#  'Alisahib Huseynov': 'Start',
#  'Ali Ibrahimov': 'Start',
#  'Irshad Aliyev': 'Stub',
#  'Mamed Iskenderov': 'Start',
#  'Vidadi Isgandarov': 'Start',
#  'Ajdar Ismailov': 'C',
#  'Saftar Jafarov': 'Start',
#  'Jeyhun Jalilov': 'Start',
#  'Arastun Javadov': 'Stub',
#  'Rovshan Javadov': 'C',
#  'Anar Karimov': 'Start',
#  'Boris Kevorkov': 'Start',
#  'Gurban Khalilov': 'Start',
#  'Ahmad Kordary': 'Stub',
#  'Lutfali bey Behbudov': 'C',
#  'Ilham Madatov': 'Start',
#  'Makhmud Mamed-Guliev': 'Start',
#  'Majnun Mammadov': 'Start',
#  'Musa Mammadov': 'Start',
#  'Ramin Mammadov': 'Start',
#  'Elshad Mirbashir oghlu': 'C',
#  'Tahir Mirkishili': 'Start',
#  'Movsum Samadov': 'C',
#  'Fuad Naghiyev': 'Start',
#  'Eldar Namazov': 'Start',
#  'Namig Nasrullayev': 'Stub',
#  'Siyavush Novruzov': 'C',
#  'Zahid Oruj': 'Start',
#  'Sadig Rahimov': 'C',
#  'Suleyman Rahimov': 'C',
#  'Huseyn Rahmanov': 'Stub',
#  'Rovshen Rzayev': 'Start',
#  'Hasan Seyidov': 'Stub',
#  'Parviz Shahbazov': 'Start',
#  'Mammad agha Shahtakhtinski': 'C',
#  'Abid Sharifov': 'Start',
#  'Shirali Akhundov': 'C',
#  'Ikhtiyar Shirinov': 'Stub',
#  'Bakhtiyar Vahabzadeh': 'C',
#  'Vugar Mustafayev (minister)': 'Start',
#  'Yusif Ziya Talibzadeh': 'GA',
#  'Nurali Yusifbayli': 'Start',
#  'Keith Bell (Bahamian politician)': 'Start',
#  'Harold Christie': 'Start',
#  'Timothy Donaldson': 'C',
#  'Eugene Dupuch': 'Start',
#  'Joseph Robert Love': 'C',
#  'McKell Bonaby': 'Stub',
#  'Pakesia Parker-Edgecombe': 'Start',
#  'Mohammed Isa Al Abbasi': 'Stub',
#  'Abdulla Adel Fakhro': 'Start',
#  'Abdullah bin Isa Al Khalifa': 'Start',
#  'Kamal Ahmed (politician)': 'Stub',
#  'Mohamed Ali Hasan Ali': 'Stub',
#  'Khalid Almoayed': 'Stub',
#  'Aymen Tawfeeq Almoayed': 'Start',
#  'Nazar Al Baharna': 'Start',
#  'Mahmood Al Bahrani': 'Stub',
#  'Ammar Al Bannai': 'Start',
#  'Jawad Fairooz': 'Start',
#  'Qasim Fakhro': 'Start',
#  'Faisal al-Hamar': 'Stub',
#  'Nabeel bin Yaqub Al-Hamar': 'Stub',
#  'Isa bin Abdulrahman Al Hammadi': 'Stub',
#  'Jameel Humadan': 'Start',
#  'Isa bin Ibrahim Al Khalifa': 'Stub',
#  'Fahmi al-Jowder': 'Stub',
#  'Saud Kanoo': 'Stub',
#  'Essam Khalaf': 'Stub',
#  'Abdullah bin Hamad bin Isa Al Khalifa': 'Start',
#  'Ahmed bin Mohamed Al Khalifa': 'Stub',
#  'Ali bin Khalifa Al Khalifa': 'Stub',
#  'Hala bint Mohammed Al Khalifa': 'Start',
#  'Ibrahim ibn Khalifa Al Khalifa': 'Start',
#  'Mai bint Mohammed Al Khalifa': 'Start',
#  'Salman bin Khalifa Al Khalifa': 'Stub',
#  'Hamad Al Kooheji': 'Stub',
#  'Abdullatif Al-Mahmood': 'Stub',
#  'Rasheed Mohammed Al Maraj': 'Stub',
#  'Khalid Al Maskati': 'Stub',
#  'Abdulhussain bin Ali Mirza': 'Stub',
#  'Mohammed Al-Buainain': 'Start',
#  'Mohammed bin Khalifa bin Ahmed': 'C',
#  'Mohammed bin Khalifa bin Ali Al Khalifa': 'Start',
#  'Abdulrahman al-Nuaimi': 'Start',
#  'Ammar Qambar': 'Start',
#  'Isa Qassim': 'GA',
#  'Abdulla Hassan Saif': 'Stub',
#  'Ali bin Saleh Al Saleh': 'Stub',
#  'Ahmed Al-Salloum': 'Start',
#  'Salman bin Hamad Al Khalifa': 'C',
#  'Abdul Motaleb': 'Stub',
#  'Abdus Salam (Chattogram politician)': 'Stub',
#  'Abul Hashim': 'C',
#  'Oli Ahad': 'Start',
#  'Chowdhury Shamsuddin Ahmed': 'Stub',
#  'Farid Ahmed': 'Stub',
#  'Muzaffar Ahmed (NAP politician)': 'Start',
#  'AKM Hafizuddin': 'Stub',
#  'Mohammad Manjur Alam': 'Start',
#  'M Hossain Ali': 'Start',
#  'Aminul Islam Rabel': 'Stub',
#  'Mohammad A. Arafat': 'GA',
#  'Ashab Uddin Ahmad': 'B',
#  'Shafiqur Rahman Badsha': 'Stub',
#  'Selina Banu': 'Start',
#  'Nurul Huq Bhuiyan': 'Stub',
#  'Birendra Kishore Roaza': 'Stub',
#  'Bishnu Chattopadhyay': 'Start',
#  'AKM Fazlul Kabir Chowdhury': 'Start',
#  'Aminul Islam Chowdhury': 'Start',
#  'Anwarul Karim Chowdhury': 'C',
#  'Moinuddin Ahmed Chowdhury': 'C',
#  'Sarwar Jan Chowdhury': 'Stub',
#  'Shahinur Pasha Chowdhury': 'Start',
#  'Yusuf Ali Chowdhury': 'Start',
#  'Haji Mohammad Danesh': 'C',
#  'Pulin De': 'Start',
#  'James Leo Ferguson': 'C',
#  'Abdul Halim Ghaznavi': 'Start',
#  'Debendra Nath Ghosh': 'Stub',
#  'Ranesh Das Gupta': 'Start',
#  'AKM Fazlul Haque (Jatiya Party politician)': 'Stub',
#  'Syed Najmuddin Hashim': 'Start',
#  'M. Anwar Hossain': 'C',
#  'Nozir Hossain': 'Start',
#  'Husam Uddin Chowdhury Fultali': 'Start',
#  'Syed Muhammad Ibrahim': 'Start',
#  'Abul Kashem': 'C',
#  'Abul Kashem Khan': 'C',
#  'Hatem Ali Khan': 'Start',
#  'Muhammad Hamidullah Khan': 'C',
#  'Yar Mohammad Khan': 'C',
#  'Kazi Abdus Shahid Lal': 'Start',
#  'Jyotirindra Bodhipriya Larma': 'Stub',
#  'Shamima Harun Lubna': 'Stub',
#  'Manik Lal Ray': 'Stub',
#  'Manjurul Imam': 'Stub',
#  'Mushrefa Mishu': 'Start',
#  'Moin Uddin (politician)': 'Stub',
#  'Fazlul Haque Montu': 'Stub',
#  'Mujahidul Islam Selim': 'Start',
#  'Mujibur Rahman (Chattogram politician)': 'Stub',
#  'Shafiul Alam Chowdhury Nadel': 'Start',
#  'SM Nuruzzaman': 'Stub',
#  'Shamsul Huda Panchbagi': 'B',
#  'Muhammad Bayazeed Khan Panni': 'C',
#  'Ferdous Ahmed Qureshi': 'Start',
#  'Asheq Ullah Rafiq': 'Stub',
#  'Habibar Rahman': 'Stub',
#  'M. M. Rahmatullah': 'C',
#  'Golam Maula Rony': 'Start',
#  'Devasish Roy': 'Start',
#  'Mahmudul Haque Sayem': 'Stub',
#  'Maulana Shakhawat': 'Stub',
#  'Abul Kalam Shamsuddin': 'Start',
#  'Badruddoza Ahmed Shuja': 'Stub',
#  'Sourendra Nath Chakraborty': 'Start',
#  'Mohammad Sultan': 'Start',
#  'Syed Sayedul Haque Suman': 'Start',
#  'Mohammad Toaha': 'Start',
#  'Badruddin Umar': 'C',
#  'Zahidunnabi Dewan Shamim': 'Start',
#  'Mohammad Zillur Rahman': 'Start',
#  'Elliott Belgrave': 'Start',
#  'Chad Blackman': 'Start',
#  'Santia Bradshaw': 'Start',
#  'Sonia Browne': 'Stub',
#  'Michael A. Carrington': 'Start',
#  'William Fondleroy Duguid': 'Start',
#  'Reginald Farley': 'Stub',
#  'Adrian Forde': 'Stub',
#  'Cynthia Y. Forde': 'Start',
#  'Ian Gooding-Edghill': 'Stub',
#  'Damien K. A. Griffith': 'Stub',
#  'Crystal Haynes': 'Stub',
#  'Philip St. Hill': 'Stub',
#  'Kirk Matthew Humphrey': 'Stub',
#  'Davidson Ishmael': 'Stub',
#  'Colin Everett Jordan': 'Stub',
#  'John Andrew King': 'Start',
#  'Shantal Munro-Knight': 'Stub',
#  'Glyne Murray': 'Stub',
#  "Charles Duncan O'Neal": 'Start',
#  'Samuel Jackman Prescod': 'C',
#  'Shanika Roberts-Odle': 'Stub',
#  'Ryan Straughn': 'Stub',
#  'Dwight Sutherland': 'Stub',
#  'Kerrie Symmonds': 'Start',
#  'Yury Ambrazevich': 'Stub',
#  'Aliaksandr Azarau': 'GA',
#  'Lyavon Barshchewski': 'Stub',
#  'Siarhei Cherachen': 'Start',
#  'Zmitser Dashkevich': 'Start',
#  'Siamion Domash': 'Stub',
#  'Tsimafei Dranchuk': 'Start',
#  'Alaksandar Dubko': 'Stub',
#  'Gennady Grushevoy': 'C',
#  'Moshe Gutman': 'Stub',
#  'Uładzimir Hančaryk': 'Stub',
#  'Tamaš Hryb': 'C',
#  'Anatoĺ Kalinin': 'Start',
#  'Voĺha Karač': 'C',
#  'Uładzisłau Kazłouski': 'Start',
#  'Tadeusz Kościuszko': 'FA',
#  'Ivan Kubrakov': 'Start',
#  'Vladimir Kumets': 'C',
#  'Valery Levaneuski': 'C',
#  'Uladzimir Mackievič': 'C',
#  'V. L. Mukha': 'Stub',
#  'Jan Pazniak': 'Stub',
#  'Aleksandr Potupa': 'C',
#  'Pyotr Prakapovich': 'Stub',
#  'Alexander Radkov': 'Start',
#  'Symon Rak-Michajłoŭski': 'GA',
#  'Vladimir Rusakevich': 'Start',
#  'Ihar Rynkevich': 'C',
#  'Valery Sakhashchyk': 'B',
#  'Dominik Semashko': 'GA',
#  'Aliaksandr Shakutsin': 'C',
#  'Nikolai Shelyagovich': 'Start',
#  'Jan Stankievič': 'Start',
#  'Mikola Statkevich': 'GA',
#  'Sergei Tikhanovsky': 'C',
#  'Aleksandr Turchin': 'Stub',
#  'Yury Voskresensky': 'C',
#  'Edward Woyniłłowicz': 'B',
#  'Ivan Yermachenka': 'Start',
#  'Manuel Abramowicz': 'Stub',
#  'Rudy Aernoudt': 'C',
#  'Herman Baltia': 'Start',
#  'Jan Béghin': 'Start',
#  'Frank Beke': 'Stub',
#  'Gustave Boël': 'Start',
#  'Pol Clovis Boël': 'Start',
#  'Antoine Brun': 'Start',
#  'Fernand Cocq': 'Stub',
#  'Émile Coulonvaux': 'Stub',
#  'Auguste Couvreur': 'Stub',
#  'Nico Cué': 'Start',
#  'Pierre David (mayor)': 'GA',
#  'Marcel de Baer': 'C',
#  'August De Boodt': 'Start',
#  'Norbert De Cuyper': 'Start',
#  'Dirk De fauw': 'Start',
#  'René De Feyter': 'Stub',
#  'François-Philippe de Haussy': 'Stub',
#  'Victor de Laveleye': 'Start',
#  'Édouard Descamps': 'Start',
#  'José Desmarets': 'Stub',
#  'Émile van Dievoet': 'C',
#  'Marc Drumaux': 'Start',
#  'Jos Dupré': 'Stub',
#  'Françoise Dupuis': 'Stub',
#  'Veerle Geerinckx': 'Start',
#  "Eugène Goblet d'Alviella": 'Start',
#  'Julien Goekint': 'Start',
#  'Jean-Pierre Grafé': 'Stub',
#  'Jacques Grippa': 'Stub',
#  'Guy Hance': 'Stub',
#  'Joris Helleputte': 'Start',
#  'Lucienne Herman-Michielsens': 'Start',
#  'Jules Hiernaux': 'Stub',
#  'Julius Hoste Jr.': 'Start',
#  'Norbert Hougardy': 'Stub',
#  'Joseph Houssa': 'Stub',
#  'Vincent Houssiau': 'Start',
#  'Pierre Van Humbeeck': 'Stub',
#  'Dorah Ilunga': 'Start',
#  'Pierre Imperiali': 'Stub',
#  'Jean-François Istasse': 'Stub',
#  'Milou Jeunehomme': 'Stub',
#  'Georges Kaeckenbeeck': 'Start',
#  'André Kempinaire': 'Stub',
#  'Ahmet Koç (politician)': 'Start',
#  'Willy Kuijpers': 'Stub',
#  'Rachid Madrane': 'Start',
#  'Luc Michel': 'C',
#  'Fientje Moerman': 'Start',
#  'André Molitor': 'Start',
#  'Jean Pede': 'Start',
#  'Pierre Emmanuel Félix Chazal': 'C',
#  'Jean-Marie Piret': 'Start',
#  'André-Eugène Pirson': 'Start',
#  'Marjet Van Puymbroeck': 'Stub',
#  'Jean Richardot the Younger': 'Start',
#  'Gustave Rolin-Jaequemyns': 'C',
#  'Hippolyte Rolin': 'Stub',
#  'Father Samuel': 'C',
#  'Louis-Joseph Seutin': 'Start',
#  'Alfons Siffer': 'Start',
#  'Cyrille Tahay': 'Stub',
#  'Jacques Timmermans': 'Stub',
#  'Robert Urbain': 'Stub',
#  'Adolphe Van Glabbeke': 'Start',
#  'Gaëtan Van Goidsenhoven': 'C',
#  'Jacques Van Gompel': 'Start',
#  'Johan Verbeke': 'Start',
#  'Yvan Verougstraete': 'Start',
#  'Lodewijk Verreycken': 'Start',
#  'Louis Waltniel': 'Stub',
#  'Yves de Wasseige': 'Start',
#  'Roger Windels': 'Start',
#  'Jacques van Ypersele de Strihou': 'C',
#  'Nemencio Acosta': 'Stub',
#  'Basilio Ah': 'Stub',
#  'Beverly Castillo': 'Stub',
#  'Charles Bartlett Hyde': 'Start',
#  'Glenn Godfrey': 'Start',
#  'Alexander Albert Hunter': 'Start',
#  'Elfreda Reyes': 'C',
#  'Bert Tucker': 'C',
#  'Woldrich Harrison Courtenay': 'Stub',
#  'Arnauld Antoine Akodjènou': 'C',
#  'Jules-Armand Aniambossou': 'Start',
#  'Francis Covi': 'Stub',
#  'Sefou Fagbohoun': 'Stub',
#  'Louis Hunkanrin': 'C',
#  'Louis Ignacio-Pinto': 'Stub',
#  'Arouna Mama': 'Start',
#  'D. N. Dhungyel': 'Stub',
#  'Dorjee Wangmo': 'Stub',
#  'Ugyen Dorji (DNT politician)': 'Start',
#  'Zangley Dukpa': 'Stub',
#  'Dupthob': 'Stub',
#  'Choki Gyeltshen': 'Stub',
#  'Sherub Gyeltshen': 'Start',
#  'Choida Jamtsho': 'Start',
#  'Rinzin Jamtsho': 'Stub',
#  'Shingkhar Lam': 'Start',
#  'Tshewang Lhamo': 'Start',
#  'Kuenga Loday': 'Stub',
#  'Dorji Namgyal': 'Stub',
#  'Jigme Namgyal (Bhutan)': 'C',
#  'Kunzang C. Namgyel': 'Start',
#  'Wangdi Norbu': 'Stub',
#  'Pema Chewang': 'Start',
#  'Pema Gyamtsho': 'Start',
#  'Kinga Penjor': 'Stub',
#  'Yeshey Penjor': 'Start',
#  'Thakur S. Powdyel': 'C',
#  'Jai Bir Rai': 'Start',
#  'Karma Rangdol': 'Stub',
#  'Chogyal Dago Rigdzin': 'Stub',
#  'Loknath Sharma': 'Start',
#  'Tenzin (politician)': 'Stub',
#  'Sonam Tobgye': 'Start',
#  'Dorji Tshering': 'Start',
#  'Kinga Tshering': 'Start',
#  'Namgay Tshering': 'Start',
#  'Ugyen Tshering': 'Stub',
#  'Jigme Wangchuk': 'Stub',
#  'Lhatu Wangchuk': 'Stub',
#  'Khandu Wangchuk': 'Start',
#  'Norbu Wangchuk': 'Stub',
#  'Tshering Wangchuk': 'Start',
#  'Karma Donnen Wangdi': 'Start',
#  'Tshencho Wangdi': 'Start',
#  'Ugyen Wangdi': 'Stub',
#  'Dechen Wangmo (politician)': 'Start',
#  'Dechen Zangmo': 'Stub',
#  'Neten Zangmo': 'Start',
#  'Nidup Zangpo': 'Stub',
#  'Yeshey Zimba': 'Start',
#  'Botche Candé': 'Stub',
#  'Juliano Fernandes': 'Stub',
#  'Teodora Inácia Gomes': 'C',
#  'Desejado Lima da Costa': 'Stub',
#  'Aristide Menezes': 'Stub',
#  'Florentino Mendes Pereira': 'Stub',
#  'Carmelita Pires': 'Start',
#  'Agnelo Regalla': 'Start',
#  'Nataniel Aguirre': 'C',
#  'Francisco Argandoña': 'Start',
#  'Atanasio de Urioste Velasco': 'GA',
#  'Isaac Ávalos': 'Stub',
#  'Augusto Céspedes': 'Start',
#  'Adolfo Chávez': 'Stub',
#  'Chi Hyun Chung': 'C',
#  'Pantaleón Dalence': 'C',
#  'Rafael Peña': 'Start',
#  'Marcelo Elío': 'Stub',
#  'Marcial Fabricano': 'Start',
#  'Fernando Eloy Guachalla': 'Stub',
#  'Toribia Lero Quispe': 'Stub',
#  'Antonio Machaca': 'Stub',
#  'Adolfo Mendoza': 'Stub',
#  'Manuel de Molina Zamudio': 'C',
#  'Pedro Domingo Murillo': 'Start',
#  "Francisco Burdett O'Connor": 'GA',
#  'Manuel Luis de Oliden': 'Stub',
#  'Simón Iturri Patiño': 'C',
#  'Bonifacio Pinedo': 'B',
#  'Julio Pinedo': 'Start',
#  'Gary Prado Salmón': 'Start',
#  'José Mariano Serrano': 'Stub',
#  'Moisés Torres (politician)': 'Start',
#  'Fernando Vargas Mosua': 'Start',
#  'Jaime de Zudáñez': 'Start',
#  'Kemal Ademović': 'Stub',
#  'Mehmed Alajbegović': 'C',
#  'Boško Baškot': 'Stub',
#  'Salko Bukvarević': 'Start',
#  'Sabina Ćudić': 'Start',
#  'Dženan Đonlagić': 'Start',
#  'Edin Forto': 'C',
#  'Dževad Galijašević': 'C',
#  'Josip Grubeša': 'Start',
#  'Ankica Gudeljević': 'Start',
#  'Hakija Hadžić': 'Start',
#  'Mirsad Hadžikadić': 'Start',
#  'Sanjin Halimović': 'Start',
#  'Sevlid Hurtić': 'C',
#  'Husein Miljković': 'GA',
#  'Jasmin Imamović': 'Start',
#  'Adamir Jerković': 'C',
#  'Esed Kadrić': 'Stub',
#  'Mehmed Kapetanović': 'Start',
#  'Osman Karabegović': 'C',
#  'Rusmir Mahmutćehajić': 'Start',
#  'Amor Mašović': 'Start',
#  'Božidar Matić': 'C',
#  'Dragan Mektić': 'C',
#  'Ademaga Mešić': 'C',
#  'Jelka Miličević': 'Start',
#  'Abdulah Mutapčić': 'Stub',
#  'Abdulah Nakaš': 'Start',
#  'Damir Nikšić': 'C',
#  'Ismet Popovac': 'FA',
#  'Hakija Pozderac': 'Start',
#  'Hamdija Pozderac': 'C',
#  'Nurija Pozderac': 'Start',
#  'Đuro Pucar': 'C',
#  'Svetozar Pudarić': 'Start',
#  'Alen Šeranić': 'Start',
#  'Uglješa Uzelac': 'Start',
#  'Nezir Škaljić': 'C',
#  'Ibrahim Spahić': 'Start',
#  'Jelena Trivić': 'C',
#  'Milan Uzelac': 'Start',
#  'Dragan Vikić': 'C',
#  'Miloš Vukašinović': 'Start',
#  'Philip Matante': 'C',
#  'Leetile Disang Raditladi': 'C',
#  'Patrick van Rensburg': 'C',
#  'Tobias de Aguiar': 'Stub',
#  'Medeiros e Albuquerque': 'Start',
#  'Léo de Almeida Neves': 'Stub',
#  'Antônio Pinto Chichorro da Gama': 'Stub',
#  'Cipriano Barata': 'Start',
#  'Jader Barbalho Filho': 'Stub',
#  'Irani Barbosa': 'Stub',
#  'Djalma Bastos de Morais': 'Stub',
#  'Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan': 'Stub',
#  'Natália Bastos Bonavides': 'Stub',
#  'Marcos Braz': 'Stub',
#  'Amador Bueno': 'Start',
#  'Maurício Campos de Medeiros': 'Start',
#  'Marcelo Cecé': 'Stub',
#  'Izolda Cela': 'GA',
#  'Margarete Coelho': 'Start',
#  'Paulo Corrêa': 'Start',
#  'Miguel Couto': 'Start',
#  'João Cunha (politician)': 'Stub',
#  'Manuel Jacinto Nogueira da Gama, Marquis of Baependi': 'Start',
#  'Aécio de Borba': 'Stub',
#  'José Abílio Silva de Santana': 'Stub',
#  'Alércio Dias': 'Stub',
#  'Délio dos Santos': 'Stub',
#  'Ademar Frederico Duwe': 'Stub',
#  'Paulo Cesar Farias': 'Start',
#  'Emília Fernandes': 'C',
#  'José Carlos da Silva Mayrink Ferrão': 'Start',
#  'Juscelino Filho': 'Start',
#  'Pedro Paulino de Fonseca': 'Stub',
#  'Francisco Julião': 'Stub',
#  'Jofran Frejat': 'Stub',
#  'Almir Gabriel': 'GA',
#  'Joaquim Gomes de Souza': 'Start',
#  ...}

# %%
#checking if there are any None values coming in the output
unique_values = set(ores_score.values())

print(unique_values)
# Out:
# {'B', 'Start', 'C', 'Stub', 'GA', 'FA'}

# %%
#printing the error rate
print(f'The error rate is {len(no_ores_score)/len(pol_info)}%.')
# Out:
# The error rate is 0.0%.

# %% [markdown]
# # Step 3
# Combining the Datasets

# %% [markdown]
# ### Creating country mapping

# %%
pop = pd.read_csv('population_by_country_AUG.2024.csv') #uploading the population dataset

# %%
region = None
country_region_mapping = []

for index, row in pop.iterrows():
    geography = row['Geography']
    population = row['Population']

    if geography.isupper():#if all letters caps its a region else a country
        region = geography
    else:
        country_region_mapping.append({'country':geography,'region':region,'population':population})

# %%
country_region_pop_df = pd.DataFrame(country_region_mapping) #convert the dicionary to a dataframe

# %%
ores_score_df =  pd.DataFrame(list(ores_score.items()), columns=['Article', 'Score']) #converting ores score dictionary to dataframe

# %%
articles_rev_id_df = pd.DataFrame(list(pol_info.items()), columns=['Article', 'RevID']) #converting the dictionary fro articles and the rev id to a dataframe

# %% [markdown]
# Merging dataframes to get revID and Scores for article in a single dataframe

# %%
articles_info_df = pd.merge(ores_score_df, articles_rev_id_df, how='inner', on='Article')

# %%
articles_info_df.head()
# Out:
#                 Article  Score       RevID
# 0        Majah Ha Adrif  Start  1233202991
# 1     Haroon al-Afghani      B  1230459615
# 2           Tayyab Agha  Start  1225661708
# 3  Khadija Zahra Ahmadi   Stub  1234741562
# 4        Aziza Ahmadyar  Start  1195651393

# %% [markdown]
# Merging the articles_info_df with initial dataset on poiltiicans to get country

# %%
articles_info_final_df = pd.merge(articles_info_df,pol, how = 'inner', left_on = 'Article', right_on = 'name')
articles_info_final_df = articles_info_final_df.drop(columns=['name']) #dropping name since its repetative

# %%
articles_info_final_df = articles_info_final_df.drop(columns=['url']) #dropping the url since its not required

# %%
articles_info_final_df.head()
# Out:
#                 Article  Score       RevID      country
# 0        Majah Ha Adrif  Start  1233202991  Afghanistan
# 1     Haroon al-Afghani      B  1230459615  Afghanistan
# 2           Tayyab Agha  Start  1225661708  Afghanistan
# 3  Khadija Zahra Ahmadi   Stub  1234741562  Afghanistan
# 4        Aziza Ahmadyar  Start  1195651393  Afghanistan

# %% [markdown]
# ### Checking which countries are not present in both the datasets

# %%
country_first_dataset = articles_info_final_df['country'].unique() #getting unique countries in first dataset and the second
country_second_dataset = country_region_pop_df['country'].unique()

# %%
country_first_set = set(country_first_dataset) #converting list to set for intersection operation
country_second_set = set(country_second_dataset)

# Find common countries in both datasets
common_countries = list(country_first_set.intersection(country_second_set))

# %%
unique_to_first = country_first_set - country_second_set #getting countires only present in first dataset
unique_to_second = country_second_set - country_first_set #getting countries only present in second dataset

# Write non-common countries to a text file
with open('wp_countries_no_match.txt', 'w') as file:
    file.write("Countries only in first dataset:\n")
    for country in unique_to_first:
        file.write(f"{country}\n")
    file.write("\nCountries only in second dataset:\n")
    for country in unique_to_second:
        file.write(f"{country}\n")

# %% [markdown]
# Making final dataframe

# %%
#filter datasets for common countries only
articles_info_final_df_filtered = articles_info_final_df[articles_info_final_df['country'].isin(common_countries)]
country_region_pop_df_filtered = country_region_pop_df[country_region_pop_df['country'].isin(common_countries)]

# %%
#merging the datasets to get final dataframe
merged_df = pd.merge(articles_info_final_df_filtered, country_region_pop_df_filtered, on='country', how='inner')
# Out:
#                    Article  Score       RevID      country          region  \
# 0           Majah Ha Adrif  Start  1233202991  Afghanistan      SOUTH ASIA
# 1        Haroon al-Afghani      B  1230459615  Afghanistan      SOUTH ASIA
# 2              Tayyab Agha  Start  1225661708  Afghanistan      SOUTH ASIA
# 3     Khadija Zahra Ahmadi   Stub  1234741562  Afghanistan      SOUTH ASIA
# 4           Aziza Ahmadyar  Start  1195651393  Afghanistan      SOUTH ASIA
# ...                    ...    ...         ...          ...             ...
# 6931      Josiah Tongogara      C  1203429435     Zimbabwe  EASTERN AFRICA
# 6932     Langton Towungana   Stub  1246280093     Zimbabwe  EASTERN AFRICA
# 6933     Sengezo Tshabangu  Start  1228478288     Zimbabwe  EASTERN AFRICA
# 6934   Herbert Ushewokunze   Stub   959111842     Zimbabwe  EASTERN AFRICA
# 6935          Denis Walker      C  1247902630     Zimbabwe  EASTERN AFRICA
#
#       population
# 0           42.4
# 1           42.4
# 2           42.4
# 3           42.4
# 4           42.4
# ...          ...
# 6931        16.7
# 6932        16.7
# 6933        16.7
# 6934        16.7
# 6935        16.7
#
# [6936 rows x 6 columns]

# %%
merged_df.head()
# Out:
#                 Article  Score       RevID      country      region  \
# 0        Majah Ha Adrif  Start  1233202991  Afghanistan  SOUTH ASIA
# 1     Haroon al-Afghani      B  1230459615  Afghanistan  SOUTH ASIA
# 2           Tayyab Agha  Start  1225661708  Afghanistan  SOUTH ASIA
# 3  Khadija Zahra Ahmadi   Stub  1234741562  Afghanistan  SOUTH ASIA
# 4        Aziza Ahmadyar  Start  1195651393  Afghanistan  SOUTH ASIA
#
#    population
# 0        42.4
# 1        42.4
# 2        42.4
# 3        42.4
# 4        42.4

# %%
#changing order of columns and rename it as per assignment
ordered_df = merged_df[['country', 'region', 'population', 'Article', 'RevID', 'Score']]

# Rename columns to match the desired names
ordered_df.columns = ['country', 'region', 'population', 'article_title', 'revision_id', 'article_quality']

# Save to CSV
ordered_df.to_csv('wp_politicians_by_country.csv', index=False)

# %% [markdown]
# # Step 4
# Analysis

# %%
ordered_df.head()
# Out:
#        country      region  population         article_title  revision_id  \
# 0  Afghanistan  SOUTH ASIA        42.4        Majah Ha Adrif   1233202991
# 1  Afghanistan  SOUTH ASIA        42.4     Haroon al-Afghani   1230459615
# 2  Afghanistan  SOUTH ASIA        42.4           Tayyab Agha   1225661708
# 3  Afghanistan  SOUTH ASIA        42.4  Khadija Zahra Ahmadi   1234741562
# 4  Afghanistan  SOUTH ASIA        42.4        Aziza Ahmadyar   1195651393
#
#   article_quality
# 0           Start
# 1               B
# 2           Start
# 3            Stub
# 4           Start

# %%
#define high quality articles
ordered_df['is_high_quality'] = ordered_df['article_quality'].isin(['FA', 'GA'])
# Out:
# /var/folders/4g/nhvf99_175n0b7w76qwfxrkc0000gn/T/ipykernel_68114/3166884357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ordered_df['is_high_quality'] = ordered_df['article_quality'].isin(['FA', 'GA'])

# %% [markdown]
# ### Calculating on a country basis

# %%
country_stats = ordered_df.groupby('country').agg(
    total_articles=('article_title', 'count'),
    high_quality_articles=('is_high_quality', 'sum'),
    population=('population', 'first'),  # Use the first population entry, assuming it's consistent per country
    region=('region', 'first')  # Use the first region entry, assuming each country has a single region
).reset_index()

# %%
#per capita vavlues
country_stats['total_articles_per_capita'] = country_stats['total_articles'] / country_stats['population']
country_stats['high_quality_articles_per_capita'] = country_stats['high_quality_articles'] / country_stats['population']

# %% [markdown]
# ### Calculating on a regiaonal basis

# %%
region_stats = country_stats.groupby('region').agg(
    total_articles=('total_articles', 'sum'),
    high_quality_articles=('high_quality_articles', 'sum'),
    population=('population', 'sum')  # Sum populations across countries in each region
).reset_index()

# %%
#per capita values
region_stats['total_articles_per_capita'] = region_stats['total_articles'] / region_stats['population']
region_stats['high_quality_articles_per_capita'] = region_stats['high_quality_articles'] / region_stats['population']

# %% [markdown]
# # Step 5
# Results

# %%
# 1. Top 10 countries by coverage
top_10_countries_coverage = country_stats.nlargest(12, 'total_articles_per_capita') # i did 12 since monaco and tuvalu have 0 population in dataset

# 2. Bottom 10 countries by coverage
bottom_10_countries_coverage = country_stats.nsmallest(10, 'total_articles_per_capita')

# 3. Top 10 countries by high quality
top_10_countries_high_quality = country_stats.nlargest(10, 'high_quality_articles_per_capita')

# 4. Bottom 10 countries by high quality
bottom_10_countries_high_quality = country_stats.nsmallest(10, 'high_quality_articles_per_capita')

# 5. Geographic regions by total coverage (ranked in descending order)
regions_by_total_coverage = region_stats.sort_values(by='total_articles_per_capita', ascending=False)

# 6. Geographic regions by high quality coverage (ranked in descending order)
regions_by_high_quality_coverage = region_stats.sort_values(by='high_quality_articles_per_capita', ascending=False)

# %%
top_10_countries_coverage.style.set_caption("Top 10 Countries by Coverage")
# Out:
# <style type="text/css">
# </style>
# <table id="T_23d3a">
#   <caption>Top 10 Countries by Coverage</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23d3a_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_23d3a_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_23d3a_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_23d3a_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_23d3a_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_23d3a_level0_col5" class="col_heading level0 col5" >total_articles_per_capita</th>
#       <th id="T_23d3a_level0_col6" class="col_heading level0 col6" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23d3a_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_23d3a_row0_col0" class="data row0 col0" >Monaco</td>
#       <td id="T_23d3a_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_23d3a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_23d3a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_23d3a_row0_col4" class="data row0 col4" >WESTERN EUROPE</td>
#       <td id="T_23d3a_row0_col5" class="data row0 col5" >inf</td>
#       <td id="T_23d3a_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row1" class="row_heading level0 row1" >154</th>
#       <td id="T_23d3a_row1_col0" class="data row1 col0" >Tuvalu</td>
#       <td id="T_23d3a_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_23d3a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_23d3a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_23d3a_row1_col4" class="data row1 col4" >OCEANIA</td>
#       <td id="T_23d3a_row1_col5" class="data row1 col5" >inf</td>
#       <td id="T_23d3a_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_23d3a_row2_col0" class="data row2 col0" >Antigua and Barbuda</td>
#       <td id="T_23d3a_row2_col1" class="data row2 col1" >32</td>
#       <td id="T_23d3a_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_23d3a_row2_col3" class="data row2 col3" >0.100000</td>
#       <td id="T_23d3a_row2_col4" class="data row2 col4" >CARIBBEAN</td>
#       <td id="T_23d3a_row2_col5" class="data row2 col5" >320.000000</td>
#       <td id="T_23d3a_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row3" class="row_heading level0 row3" >51</th>
#       <td id="T_23d3a_row3_col0" class="data row3 col0" >Federated States of Micronesia</td>
#       <td id="T_23d3a_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_23d3a_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_23d3a_row3_col3" class="data row3 col3" >0.100000</td>
#       <td id="T_23d3a_row3_col4" class="data row3 col4" >OCEANIA</td>
#       <td id="T_23d3a_row3_col5" class="data row3 col5" >140.000000</td>
#       <td id="T_23d3a_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row4" class="row_heading level0 row4" >93</th>
#       <td id="T_23d3a_row4_col0" class="data row4 col0" >Marshall Islands</td>
#       <td id="T_23d3a_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_23d3a_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_23d3a_row4_col3" class="data row4 col3" >0.100000</td>
#       <td id="T_23d3a_row4_col4" class="data row4 col4" >OCEANIA</td>
#       <td id="T_23d3a_row4_col5" class="data row4 col5" >130.000000</td>
#       <td id="T_23d3a_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row5" class="row_heading level0 row5" >149</th>
#       <td id="T_23d3a_row5_col0" class="data row5 col0" >Tonga</td>
#       <td id="T_23d3a_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_23d3a_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_23d3a_row5_col3" class="data row5 col3" >0.100000</td>
#       <td id="T_23d3a_row5_col4" class="data row5 col4" >OCEANIA</td>
#       <td id="T_23d3a_row5_col5" class="data row5 col5" >100.000000</td>
#       <td id="T_23d3a_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_23d3a_row6_col0" class="data row6 col0" >Barbados</td>
#       <td id="T_23d3a_row6_col1" class="data row6 col1" >25</td>
#       <td id="T_23d3a_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_23d3a_row6_col3" class="data row6 col3" >0.300000</td>
#       <td id="T_23d3a_row6_col4" class="data row6 col4" >CARIBBEAN</td>
#       <td id="T_23d3a_row6_col5" class="data row6 col5" >83.333333</td>
#       <td id="T_23d3a_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row7" class="row_heading level0 row7" >98</th>
#       <td id="T_23d3a_row7_col0" class="data row7 col0" >Montenegro</td>
#       <td id="T_23d3a_row7_col1" class="data row7 col1" >36</td>
#       <td id="T_23d3a_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_23d3a_row7_col3" class="data row7 col3" >0.600000</td>
#       <td id="T_23d3a_row7_col4" class="data row7 col4" >SOUTHERN EUROPE</td>
#       <td id="T_23d3a_row7_col5" class="data row7 col5" >60.000000</td>
#       <td id="T_23d3a_row7_col6" class="data row7 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row8" class="row_heading level0 row8" >125</th>
#       <td id="T_23d3a_row8_col0" class="data row8 col0" >Seychelles</td>
#       <td id="T_23d3a_row8_col1" class="data row8 col1" >6</td>
#       <td id="T_23d3a_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_23d3a_row8_col3" class="data row8 col3" >0.100000</td>
#       <td id="T_23d3a_row8_col4" class="data row8 col4" >EASTERN AFRICA</td>
#       <td id="T_23d3a_row8_col5" class="data row8 col5" >60.000000</td>
#       <td id="T_23d3a_row8_col6" class="data row8 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row9" class="row_heading level0 row9" >17</th>
#       <td id="T_23d3a_row9_col0" class="data row9 col0" >Bhutan</td>
#       <td id="T_23d3a_row9_col1" class="data row9 col1" >44</td>
#       <td id="T_23d3a_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_23d3a_row9_col3" class="data row9 col3" >0.800000</td>
#       <td id="T_23d3a_row9_col4" class="data row9 col4" >SOUTH ASIA</td>
#       <td id="T_23d3a_row9_col5" class="data row9 col5" >55.000000</td>
#       <td id="T_23d3a_row9_col6" class="data row9 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row10" class="row_heading level0 row10" >90</th>
#       <td id="T_23d3a_row10_col0" class="data row10 col0" >Maldives</td>
#       <td id="T_23d3a_row10_col1" class="data row10 col1" >33</td>
#       <td id="T_23d3a_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_23d3a_row10_col3" class="data row10 col3" >0.600000</td>
#       <td id="T_23d3a_row10_col4" class="data row10 col4" >SOUTH ASIA</td>
#       <td id="T_23d3a_row10_col5" class="data row10 col5" >55.000000</td>
#       <td id="T_23d3a_row10_col6" class="data row10 col6" >1.666667</td>
#     </tr>
#     <tr>
#       <th id="T_23d3a_level0_row11" class="row_heading level0 row11" >138</th>
#       <td id="T_23d3a_row11_col0" class="data row11 col0" >St. Vincent and the Grenadines</td>
#       <td id="T_23d3a_row11_col1" class="data row11 col1" >4</td>
#       <td id="T_23d3a_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_23d3a_row11_col3" class="data row11 col3" >0.100000</td>
#       <td id="T_23d3a_row11_col4" class="data row11 col4" >CARIBBEAN</td>
#       <td id="T_23d3a_row11_col5" class="data row11 col5" >40.000000</td>
#       <td id="T_23d3a_row11_col6" class="data row11 col6" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
bottom_10_countries_coverage.style.set_caption("Bottom 10 Countries by Coverage")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1441">
#   <caption>Bottom 10 Countries by Coverage</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1441_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_c1441_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_c1441_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_c1441_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_c1441_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_c1441_level0_col5" class="col_heading level0 col5" >total_articles_per_capita</th>
#       <th id="T_c1441_level0_col6" class="col_heading level0 col6" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1441_level0_row0" class="row_heading level0 row0" >31</th>
#       <td id="T_c1441_row0_col0" class="data row0 col0" >China</td>
#       <td id="T_c1441_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_c1441_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c1441_row0_col3" class="data row0 col3" >1411.300000</td>
#       <td id="T_c1441_row0_col4" class="data row0 col4" >EAST ASIA</td>
#       <td id="T_c1441_row0_col5" class="data row0 col5" >0.011337</td>
#       <td id="T_c1441_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row1" class="row_heading level0 row1" >57</th>
#       <td id="T_c1441_row1_col0" class="data row1 col0" >Ghana</td>
#       <td id="T_c1441_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_c1441_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_c1441_row1_col3" class="data row1 col3" >34.100000</td>
#       <td id="T_c1441_row1_col4" class="data row1 col4" >WESTERN AFRICA</td>
#       <td id="T_c1441_row1_col5" class="data row1 col5" >0.087977</td>
#       <td id="T_c1441_row1_col6" class="data row1 col6" >0.029326</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row2" class="row_heading level0 row2" >66</th>
#       <td id="T_c1441_row2_col0" class="data row2 col0" >India</td>
#       <td id="T_c1441_row2_col1" class="data row2 col1" >151</td>
#       <td id="T_c1441_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c1441_row2_col3" class="data row2 col3" >1428.600000</td>
#       <td id="T_c1441_row2_col4" class="data row2 col4" >SOUTH ASIA</td>
#       <td id="T_c1441_row2_col5" class="data row2 col5" >0.105698</td>
#       <td id="T_c1441_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row3" class="row_heading level0 row3" >122</th>
#       <td id="T_c1441_row3_col0" class="data row3 col0" >Saudi Arabia</td>
#       <td id="T_c1441_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_c1441_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_c1441_row3_col3" class="data row3 col3" >36.900000</td>
#       <td id="T_c1441_row3_col4" class="data row3 col4" >WESTERN ASIA</td>
#       <td id="T_c1441_row3_col5" class="data row3 col5" >0.135501</td>
#       <td id="T_c1441_row3_col6" class="data row3 col6" >0.054201</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row4" class="row_heading level0 row4" >164</th>
#       <td id="T_c1441_row4_col0" class="data row4 col0" >Zambia</td>
#       <td id="T_c1441_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_c1441_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_c1441_row4_col3" class="data row4 col3" >20.200000</td>
#       <td id="T_c1441_row4_col4" class="data row4 col4" >EASTERN AFRICA</td>
#       <td id="T_c1441_row4_col5" class="data row4 col5" >0.148515</td>
#       <td id="T_c1441_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row5" class="row_heading level0 row5" >108</th>
#       <td id="T_c1441_row5_col0" class="data row5 col0" >Norway</td>
#       <td id="T_c1441_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_c1441_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_c1441_row5_col3" class="data row5 col3" >5.500000</td>
#       <td id="T_c1441_row5_col4" class="data row5 col4" >NORTHERN EUROPE</td>
#       <td id="T_c1441_row5_col5" class="data row5 col5" >0.181818</td>
#       <td id="T_c1441_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_c1441_row6_col0" class="data row6 col0" >Israel</td>
#       <td id="T_c1441_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_c1441_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_c1441_row6_col3" class="data row6 col3" >9.800000</td>
#       <td id="T_c1441_row6_col4" class="data row6 col4" >WESTERN ASIA</td>
#       <td id="T_c1441_row6_col5" class="data row6 col5" >0.204082</td>
#       <td id="T_c1441_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row7" class="row_heading level0 row7" >45</th>
#       <td id="T_c1441_row7_col0" class="data row7 col0" >Egypt</td>
#       <td id="T_c1441_row7_col1" class="data row7 col1" >32</td>
#       <td id="T_c1441_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_c1441_row7_col3" class="data row7 col3" >105.200000</td>
#       <td id="T_c1441_row7_col4" class="data row7 col4" >NORTHERN AFRICA</td>
#       <td id="T_c1441_row7_col5" class="data row7 col5" >0.304183</td>
#       <td id="T_c1441_row7_col6" class="data row7 col6" >0.009506</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row8" class="row_heading level0 row8" >37</th>
#       <td id="T_c1441_row8_col0" class="data row8 col0" >Cote d'Ivoire</td>
#       <td id="T_c1441_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_c1441_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_c1441_row8_col3" class="data row8 col3" >30.900000</td>
#       <td id="T_c1441_row8_col4" class="data row8 col4" >WESTERN AFRICA</td>
#       <td id="T_c1441_row8_col5" class="data row8 col5" >0.323625</td>
#       <td id="T_c1441_row8_col6" class="data row8 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c1441_level0_row9" class="row_heading level0 row9" >100</th>
#       <td id="T_c1441_row9_col0" class="data row9 col0" >Mozambique</td>
#       <td id="T_c1441_row9_col1" class="data row9 col1" >11</td>
#       <td id="T_c1441_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_c1441_row9_col3" class="data row9 col3" >33.900000</td>
#       <td id="T_c1441_row9_col4" class="data row9 col4" >EASTERN AFRICA</td>
#       <td id="T_c1441_row9_col5" class="data row9 col5" >0.324484</td>
#       <td id="T_c1441_row9_col6" class="data row9 col6" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_10_countries_high_quality.style.set_caption("Top 10 Countries by High Quality")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c876b">
#   <caption>Top 10 Countries by High Quality</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c876b_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_c876b_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_c876b_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_c876b_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_c876b_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_c876b_level0_col5" class="col_heading level0 col5" >total_articles_per_capita</th>
#       <th id="T_c876b_level0_col6" class="col_heading level0 col6" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c876b_level0_row0" class="row_heading level0 row0" >98</th>
#       <td id="T_c876b_row0_col0" class="data row0 col0" >Montenegro</td>
#       <td id="T_c876b_row0_col1" class="data row0 col1" >36</td>
#       <td id="T_c876b_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_c876b_row0_col3" class="data row0 col3" >0.600000</td>
#       <td id="T_c876b_row0_col4" class="data row0 col4" >SOUTHERN EUROPE</td>
#       <td id="T_c876b_row0_col5" class="data row0 col5" >60.000000</td>
#       <td id="T_c876b_row0_col6" class="data row0 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row1" class="row_heading level0 row1" >86</th>
#       <td id="T_c876b_row1_col0" class="data row1 col0" >Luxembourg</td>
#       <td id="T_c876b_row1_col1" class="data row1 col1" >27</td>
#       <td id="T_c876b_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_c876b_row1_col3" class="data row1 col3" >0.700000</td>
#       <td id="T_c876b_row1_col4" class="data row1 col4" >WESTERN EUROPE</td>
#       <td id="T_c876b_row1_col5" class="data row1 col5" >38.571429</td>
#       <td id="T_c876b_row1_col6" class="data row1 col6" >2.857143</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_c876b_row2_col0" class="data row2 col0" >Albania</td>
#       <td id="T_c876b_row2_col1" class="data row2 col1" >70</td>
#       <td id="T_c876b_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_c876b_row2_col3" class="data row2 col3" >2.700000</td>
#       <td id="T_c876b_row2_col4" class="data row2 col4" >SOUTHERN EUROPE</td>
#       <td id="T_c876b_row2_col5" class="data row2 col5" >25.925926</td>
#       <td id="T_c876b_row2_col6" class="data row2 col6" >2.592593</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row3" class="row_heading level0 row3" >76</th>
#       <td id="T_c876b_row3_col0" class="data row3 col0" >Kosovo</td>
#       <td id="T_c876b_row3_col1" class="data row3 col1" >26</td>
#       <td id="T_c876b_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_c876b_row3_col3" class="data row3 col3" >1.700000</td>
#       <td id="T_c876b_row3_col4" class="data row3 col4" >SOUTHERN EUROPE</td>
#       <td id="T_c876b_row3_col5" class="data row3 col5" >15.294118</td>
#       <td id="T_c876b_row3_col6" class="data row3 col6" >2.352941</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row4" class="row_heading level0 row4" >90</th>
#       <td id="T_c876b_row4_col0" class="data row4 col0" >Maldives</td>
#       <td id="T_c876b_row4_col1" class="data row4 col1" >33</td>
#       <td id="T_c876b_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_c876b_row4_col3" class="data row4 col3" >0.600000</td>
#       <td id="T_c876b_row4_col4" class="data row4 col4" >SOUTH ASIA</td>
#       <td id="T_c876b_row4_col5" class="data row4 col5" >55.000000</td>
#       <td id="T_c876b_row4_col6" class="data row4 col6" >1.666667</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row5" class="row_heading level0 row5" >85</th>
#       <td id="T_c876b_row5_col0" class="data row5 col0" >Lithuania</td>
#       <td id="T_c876b_row5_col1" class="data row5 col1" >58</td>
#       <td id="T_c876b_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_c876b_row5_col3" class="data row5 col3" >2.900000</td>
#       <td id="T_c876b_row5_col4" class="data row5 col4" >NORTHERN EUROPE</td>
#       <td id="T_c876b_row5_col5" class="data row5 col5" >20.000000</td>
#       <td id="T_c876b_row5_col6" class="data row5 col6" >1.379310</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row6" class="row_heading level0 row6" >38</th>
#       <td id="T_c876b_row6_col0" class="data row6 col0" >Croatia</td>
#       <td id="T_c876b_row6_col1" class="data row6 col1" >64</td>
#       <td id="T_c876b_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_c876b_row6_col3" class="data row6 col3" >3.800000</td>
#       <td id="T_c876b_row6_col4" class="data row6 col4" >SOUTHERN EUROPE</td>
#       <td id="T_c876b_row6_col5" class="data row6 col5" >16.842105</td>
#       <td id="T_c876b_row6_col6" class="data row6 col6" >1.315789</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row7" class="row_heading level0 row7" >62</th>
#       <td id="T_c876b_row7_col0" class="data row7 col0" >Guyana</td>
#       <td id="T_c876b_row7_col1" class="data row7 col1" >17</td>
#       <td id="T_c876b_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_c876b_row7_col3" class="data row7 col3" >0.800000</td>
#       <td id="T_c876b_row7_col4" class="data row7 col4" >SOUTH AMERICA</td>
#       <td id="T_c876b_row7_col5" class="data row7 col5" >21.250000</td>
#       <td id="T_c876b_row7_col6" class="data row7 col6" >1.250000</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row8" class="row_heading level0 row8" >111</th>
#       <td id="T_c876b_row8_col0" class="data row8 col0" >Palestinian Territory</td>
#       <td id="T_c876b_row8_col1" class="data row8 col1" >61</td>
#       <td id="T_c876b_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_c876b_row8_col3" class="data row8 col3" >5.500000</td>
#       <td id="T_c876b_row8_col4" class="data row8 col4" >WESTERN ASIA</td>
#       <td id="T_c876b_row8_col5" class="data row8 col5" >11.090909</td>
#       <td id="T_c876b_row8_col6" class="data row8 col6" >1.090909</td>
#     </tr>
#     <tr>
#       <th id="T_c876b_level0_row9" class="row_heading level0 row9" >129</th>
#       <td id="T_c876b_row9_col0" class="data row9 col0" >Slovenia</td>
#       <td id="T_c876b_row9_col1" class="data row9 col1" >37</td>
#       <td id="T_c876b_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_c876b_row9_col3" class="data row9 col3" >2.100000</td>
#       <td id="T_c876b_row9_col4" class="data row9 col4" >SOUTHERN EUROPE</td>
#       <td id="T_c876b_row9_col5" class="data row9 col5" >17.619048</td>
#       <td id="T_c876b_row9_col6" class="data row9 col6" >0.952381</td>
#     </tr>
#   </tbody>
# </table>

# %%
bottom_10_countries_high_quality.style.set_caption("Bottom 10 Countries by High Quality")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ada7">
#   <caption>Bottom 10 Countries by High Quality</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ada7_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_6ada7_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_6ada7_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_6ada7_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_6ada7_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_6ada7_level0_col5" class="col_heading level0 col5" >total_articles_per_capita</th>
#       <th id="T_6ada7_level0_col6" class="col_heading level0 col6" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ada7_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_6ada7_row0_col0" class="data row0 col0" >Antigua and Barbuda</td>
#       <td id="T_6ada7_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_6ada7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6ada7_row0_col3" class="data row0 col3" >0.100000</td>
#       <td id="T_6ada7_row0_col4" class="data row0 col4" >CARIBBEAN</td>
#       <td id="T_6ada7_row0_col5" class="data row0 col5" >320.000000</td>
#       <td id="T_6ada7_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_6ada7_row1_col0" class="data row1 col0" >Bahamas</td>
#       <td id="T_6ada7_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_6ada7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6ada7_row1_col3" class="data row1 col3" >0.400000</td>
#       <td id="T_6ada7_row1_col4" class="data row1 col4" >CARIBBEAN</td>
#       <td id="T_6ada7_row1_col5" class="data row1 col5" >17.500000</td>
#       <td id="T_6ada7_row1_col6" class="data row1 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_6ada7_row2_col0" class="data row2 col0" >Barbados</td>
#       <td id="T_6ada7_row2_col1" class="data row2 col1" >25</td>
#       <td id="T_6ada7_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6ada7_row2_col3" class="data row2 col3" >0.300000</td>
#       <td id="T_6ada7_row2_col4" class="data row2 col4" >CARIBBEAN</td>
#       <td id="T_6ada7_row2_col5" class="data row2 col5" >83.333333</td>
#       <td id="T_6ada7_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_6ada7_row3_col0" class="data row3 col0" >Belize</td>
#       <td id="T_6ada7_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_6ada7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6ada7_row3_col3" class="data row3 col3" >0.500000</td>
#       <td id="T_6ada7_row3_col4" class="data row3 col4" >CENTRAL AMERICA</td>
#       <td id="T_6ada7_row3_col5" class="data row3 col5" >18.000000</td>
#       <td id="T_6ada7_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_6ada7_row4_col0" class="data row4 col0" >Benin</td>
#       <td id="T_6ada7_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_6ada7_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6ada7_row4_col3" class="data row4 col3" >13.700000</td>
#       <td id="T_6ada7_row4_col4" class="data row4 col4" >WESTERN AFRICA</td>
#       <td id="T_6ada7_row4_col5" class="data row4 col5" >0.510949</td>
#       <td id="T_6ada7_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_6ada7_row5_col0" class="data row5 col0" >Bhutan</td>
#       <td id="T_6ada7_row5_col1" class="data row5 col1" >44</td>
#       <td id="T_6ada7_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6ada7_row5_col3" class="data row5 col3" >0.800000</td>
#       <td id="T_6ada7_row5_col4" class="data row5 col4" >SOUTH ASIA</td>
#       <td id="T_6ada7_row5_col5" class="data row5 col5" >55.000000</td>
#       <td id="T_6ada7_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_6ada7_row6_col0" class="data row6 col0" >Botswana</td>
#       <td id="T_6ada7_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_6ada7_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_6ada7_row6_col3" class="data row6 col3" >2.700000</td>
#       <td id="T_6ada7_row6_col4" class="data row6 col4" >SOUTHERN AFRICA</td>
#       <td id="T_6ada7_row6_col5" class="data row6 col5" >1.111111</td>
#       <td id="T_6ada7_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_6ada7_row7_col0" class="data row7 col0" >Cape Verde</td>
#       <td id="T_6ada7_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_6ada7_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_6ada7_row7_col3" class="data row7 col3" >0.600000</td>
#       <td id="T_6ada7_row7_col4" class="data row7 col4" >WESTERN AFRICA</td>
#       <td id="T_6ada7_row7_col5" class="data row7 col5" >15.000000</td>
#       <td id="T_6ada7_row7_col6" class="data row7 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_6ada7_row8_col0" class="data row8 col0" >Chad</td>
#       <td id="T_6ada7_row8_col1" class="data row8 col1" >21</td>
#       <td id="T_6ada7_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_6ada7_row8_col3" class="data row8 col3" >18.300000</td>
#       <td id="T_6ada7_row8_col4" class="data row8 col4" >MIDDLE AFRICA</td>
#       <td id="T_6ada7_row8_col5" class="data row8 col5" >1.147541</td>
#       <td id="T_6ada7_row8_col6" class="data row8 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6ada7_level0_row9" class="row_heading level0 row9" >31</th>
#       <td id="T_6ada7_row9_col0" class="data row9 col0" >China</td>
#       <td id="T_6ada7_row9_col1" class="data row9 col1" >16</td>
#       <td id="T_6ada7_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_6ada7_row9_col3" class="data row9 col3" >1411.300000</td>
#       <td id="T_6ada7_row9_col4" class="data row9 col4" >EAST ASIA</td>
#       <td id="T_6ada7_row9_col5" class="data row9 col5" >0.011337</td>
#       <td id="T_6ada7_row9_col6" class="data row9 col6" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
regions_by_total_coverage.style.set_caption("Geographic Regions by Total Coverage")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5aef2">
#   <caption>Geographic Regions by Total Coverage</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5aef2_level0_col0" class="col_heading level0 col0" >region</th>
#       <th id="T_5aef2_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_5aef2_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_5aef2_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_5aef2_level0_col4" class="col_heading level0 col4" >total_articles_per_capita</th>
#       <th id="T_5aef2_level0_col5" class="col_heading level0 col5" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5aef2_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_5aef2_row0_col0" class="data row0 col0" >NORTHERN EUROPE</td>
#       <td id="T_5aef2_row0_col1" class="data row0 col1" >189</td>
#       <td id="T_5aef2_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_5aef2_row0_col3" class="data row0 col3" >27.800000</td>
#       <td id="T_5aef2_row0_col4" class="data row0 col4" >6.798561</td>
#       <td id="T_5aef2_row0_col5" class="data row0 col5" >0.323741</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_5aef2_row1_col0" class="data row1 col0" >OCEANIA</td>
#       <td id="T_5aef2_row1_col1" class="data row1 col1" >71</td>
#       <td id="T_5aef2_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_5aef2_row1_col3" class="data row1 col3" >11.100000</td>
#       <td id="T_5aef2_row1_col4" class="data row1 col4" >6.396396</td>
#       <td id="T_5aef2_row1_col5" class="data row1 col5" >0.090090</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_5aef2_row2_col0" class="data row2 col0" >CARIBBEAN</td>
#       <td id="T_5aef2_row2_col1" class="data row2 col1" >213</td>
#       <td id="T_5aef2_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_5aef2_row2_col3" class="data row2 col3" >36.600000</td>
#       <td id="T_5aef2_row2_col4" class="data row2 col4" >5.819672</td>
#       <td id="T_5aef2_row2_col5" class="data row2 col5" >0.245902</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_5aef2_row3_col0" class="data row3 col0" >SOUTHERN EUROPE</td>
#       <td id="T_5aef2_row3_col1" class="data row3 col1" >785</td>
#       <td id="T_5aef2_row3_col2" class="data row3 col2" >53</td>
#       <td id="T_5aef2_row3_col3" class="data row3 col3" >151.500000</td>
#       <td id="T_5aef2_row3_col4" class="data row3 col4" >5.181518</td>
#       <td id="T_5aef2_row3_col5" class="data row3 col5" >0.349835</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_5aef2_row4_col0" class="data row4 col0" >CENTRAL AMERICA</td>
#       <td id="T_5aef2_row4_col1" class="data row4 col1" >186</td>
#       <td id="T_5aef2_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_5aef2_row4_col3" class="data row4 col3" >51.300000</td>
#       <td id="T_5aef2_row4_col4" class="data row4 col4" >3.625731</td>
#       <td id="T_5aef2_row4_col5" class="data row4 col5" >0.194932</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_5aef2_row5_col0" class="data row5 col0" >WESTERN EUROPE</td>
#       <td id="T_5aef2_row5_col1" class="data row5 col1" >490</td>
#       <td id="T_5aef2_row5_col2" class="data row5 col2" >21</td>
#       <td id="T_5aef2_row5_col3" class="data row5 col3" >181.300000</td>
#       <td id="T_5aef2_row5_col4" class="data row5 col4" >2.702703</td>
#       <td id="T_5aef2_row5_col5" class="data row5 col5" >0.115830</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_5aef2_row6_col0" class="data row6 col0" >EASTERN EUROPE</td>
#       <td id="T_5aef2_row6_col1" class="data row6 col1" >700</td>
#       <td id="T_5aef2_row6_col2" class="data row6 col2" >38</td>
#       <td id="T_5aef2_row6_col3" class="data row6 col3" >266.200000</td>
#       <td id="T_5aef2_row6_col4" class="data row6 col4" >2.629602</td>
#       <td id="T_5aef2_row6_col5" class="data row6 col5" >0.142750</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row7" class="row_heading level0 row7" >16</th>
#       <td id="T_5aef2_row7_col0" class="data row7 col0" >WESTERN ASIA</td>
#       <td id="T_5aef2_row7_col1" class="data row7 col1" >605</td>
#       <td id="T_5aef2_row7_col2" class="data row7 col2" >27</td>
#       <td id="T_5aef2_row7_col3" class="data row7 col3" >295.400000</td>
#       <td id="T_5aef2_row7_col4" class="data row7 col4" >2.048070</td>
#       <td id="T_5aef2_row7_col5" class="data row7 col5" >0.091401</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_5aef2_row8_col0" class="data row8 col0" >SOUTHERN AFRICA</td>
#       <td id="T_5aef2_row8_col1" class="data row8 col1" >122</td>
#       <td id="T_5aef2_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_5aef2_row8_col3" class="data row8 col3" >68.300000</td>
#       <td id="T_5aef2_row8_col4" class="data row8 col4" >1.786237</td>
#       <td id="T_5aef2_row8_col5" class="data row8 col5" >0.117130</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_5aef2_row9_col0" class="data row9 col0" >EASTERN AFRICA</td>
#       <td id="T_5aef2_row9_col1" class="data row9 col1" >663</td>
#       <td id="T_5aef2_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_5aef2_row9_col3" class="data row9 col3" >480.900000</td>
#       <td id="T_5aef2_row9_col4" class="data row9 col4" >1.378665</td>
#       <td id="T_5aef2_row9_col5" class="data row9 col5" >0.035350</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5aef2_row10_col0" class="data row10 col0" >SOUTH AMERICA</td>
#       <td id="T_5aef2_row10_col1" class="data row10 col1" >562</td>
#       <td id="T_5aef2_row10_col2" class="data row10 col2" >18</td>
#       <td id="T_5aef2_row10_col3" class="data row10 col3" >425.000000</td>
#       <td id="T_5aef2_row10_col4" class="data row10 col4" >1.322353</td>
#       <td id="T_5aef2_row10_col5" class="data row10 col5" >0.042353</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row11" class="row_heading level0 row11" >2</th>
#       <td id="T_5aef2_row11_col0" class="data row11 col0" >CENTRAL ASIA</td>
#       <td id="T_5aef2_row11_col1" class="data row11 col1" >106</td>
#       <td id="T_5aef2_row11_col2" class="data row11 col2" >5</td>
#       <td id="T_5aef2_row11_col3" class="data row11 col3" >80.400000</td>
#       <td id="T_5aef2_row11_col4" class="data row11 col4" >1.318408</td>
#       <td id="T_5aef2_row11_col5" class="data row11 col5" >0.062189</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row12" class="row_heading level0 row12" >7</th>
#       <td id="T_5aef2_row12_col0" class="data row12 col0" >NORTHERN AFRICA</td>
#       <td id="T_5aef2_row12_col1" class="data row12 col1" >301</td>
#       <td id="T_5aef2_row12_col2" class="data row12 col2" >17</td>
#       <td id="T_5aef2_row12_col3" class="data row12 col3" >255.900000</td>
#       <td id="T_5aef2_row12_col4" class="data row12 col4" >1.176241</td>
#       <td id="T_5aef2_row12_col5" class="data row12 col5" >0.066432</td>
#     </tr>
#     <tr>
#       <th id="T_5aef2_level0_row13" class="row_heading level0 row13" >15</th>
#       <td id="T_5aef2_row13_col0" class="data row13 col0" >WESTERN AFRICA</td>
#       <td id="T_5aef2_row13_col1" class="data row13 col1" >512</td>
#       <td id="T_5aef2_row13_col2" class="data row13 col2" >13</td>
#       <td id="T_5aef2_row13_col3" class="data row13 col3" >440.100000</td>
#       <td id="T_5aef2_row13_col4" class="data row13 col4" >1.163372</td>
#       <td id="T_5aef2_row13_col5" class="data row

# %%
regions_by_high_quality_coverage.style.set_caption("Geographic Regions by High Quality Coverage")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d6ae">
#   <caption>Geographic Regions by High Quality Coverage</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d6ae_level0_col0" class="col_heading level0 col0" >region</th>
#       <th id="T_2d6ae_level0_col1" class="col_heading level0 col1" >total_articles</th>
#       <th id="T_2d6ae_level0_col2" class="col_heading level0 col2" >high_quality_articles</th>
#       <th id="T_2d6ae_level0_col3" class="col_heading level0 col3" >population</th>
#       <th id="T_2d6ae_level0_col4" class="col_heading level0 col4" >total_articles_per_capita</th>
#       <th id="T_2d6ae_level0_col5" class="col_heading level0 col5" >high_quality_articles_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d6ae_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_2d6ae_row0_col0" class="data row0 col0" >SOUTHERN EUROPE</td>
#       <td id="T_2d6ae_row0_col1" class="data row0 col1" >785</td>
#       <td id="T_2d6ae_row0_col2" class="data row0 col2" >53</td>
#       <td id="T_2d6ae_row0_col3" class="data row0 col3" >151.500000</td>
#       <td id="T_2d6ae_row0_col4" class="data row0 col4" >5.181518</td>
#       <td id="T_2d6ae_row0_col5" class="data row0 col5" >0.349835</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_2d6ae_row1_col0" class="data row1 col0" >NORTHERN EUROPE</td>
#       <td id="T_2d6ae_row1_col1" class="data row1 col1" >189</td>
#       <td id="T_2d6ae_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_2d6ae_row1_col3" class="data row1 col3" >27.800000</td>
#       <td id="T_2d6ae_row1_col4" class="data row1 col4" >6.798561</td>
#       <td id="T_2d6ae_row1_col5" class="data row1 col5" >0.323741</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_2d6ae_row2_col0" class="data row2 col0" >CARIBBEAN</td>
#       <td id="T_2d6ae_row2_col1" class="data row2 col1" >213</td>
#       <td id="T_2d6ae_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_2d6ae_row2_col3" class="data row2 col3" >36.600000</td>
#       <td id="T_2d6ae_row2_col4" class="data row2 col4" >5.819672</td>
#       <td id="T_2d6ae_row2_col5" class="data row2 col5" >0.245902</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_2d6ae_row3_col0" class="data row3 col0" >CENTRAL AMERICA</td>
#       <td id="T_2d6ae_row3_col1" class="data row3 col1" >186</td>
#       <td id="T_2d6ae_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_2d6ae_row3_col3" class="data row3 col3" >51.300000</td>
#       <td id="T_2d6ae_row3_col4" class="data row3 col4" >3.625731</td>
#       <td id="T_2d6ae_row3_col5" class="data row3 col5" >0.194932</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2d6ae_row4_col0" class="data row4 col0" >EASTERN EUROPE</td>
#       <td id="T_2d6ae_row4_col1" class="data row4 col1" >700</td>
#       <td id="T_2d6ae_row4_col2" class="data row4 col2" >38</td>
#       <td id="T_2d6ae_row4_col3" class="data row4 col3" >266.200000</td>
#       <td id="T_2d6ae_row4_col4" class="data row4 col4" >2.629602</td>
#       <td id="T_2d6ae_row4_col5" class="data row4 col5" >0.142750</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_2d6ae_row5_col0" class="data row5 col0" >SOUTHERN AFRICA</td>
#       <td id="T_2d6ae_row5_col1" class="data row5 col1" >122</td>
#       <td id="T_2d6ae_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_2d6ae_row5_col3" class="data row5 col3" >68.300000</td>
#       <td id="T_2d6ae_row5_col4" class="data row5 col4" >1.786237</td>
#       <td id="T_2d6ae_row5_col5" class="data row5 col5" >0.117130</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row6" class="row_heading level0 row6" >17</th>
#       <td id="T_2d6ae_row6_col0" class="data row6 col0" >WESTERN EUROPE</td>
#       <td id="T_2d6ae_row6_col1" class="data row6 col1" >490</td>
#       <td id="T_2d6ae_row6_col2" class="data row6 col2" >21</td>
#       <td id="T_2d6ae_row6_col3" class="data row6 col3" >181.300000</td>
#       <td id="T_2d6ae_row6_col4" class="data row6 col4" >2.702703</td>
#       <td id="T_2d6ae_row6_col5" class="data row6 col5" >0.115830</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row7" class="row_heading level0 row7" >16</th>
#       <td id="T_2d6ae_row7_col0" class="data row7 col0" >WESTERN ASIA</td>
#       <td id="T_2d6ae_row7_col1" class="data row7 col1" >605</td>
#       <td id="T_2d6ae_row7_col2" class="data row7 col2" >27</td>
#       <td id="T_2d6ae_row7_col3" class="data row7 col3" >295.400000</td>
#       <td id="T_2d6ae_row7_col4" class="data row7 col4" >2.048070</td>
#       <td id="T_2d6ae_row7_col5" class="data row7 col5" >0.091401</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2d6ae_row8_col0" class="data row8 col0" >OCEANIA</td>
#       <td id="T_2d6ae_row8_col1" class="data row8 col1" >71</td>
#       <td id="T_2d6ae_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_2d6ae_row8_col3" class="data row8 col3" >11.100000</td>
#       <td id="T_2d6ae_row8_col4" class="data row8 col4" >6.396396</td>
#       <td id="T_2d6ae_row8_col5" class="data row8 col5" >0.090090</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_2d6ae_row9_col0" class="data row9 col0" >NORTHERN AFRICA</td>
#       <td id="T_2d6ae_row9_col1" class="data row9 col1" >301</td>
#       <td id="T_2d6ae_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_2d6ae_row9_col3" class="data row9 col3" >255.900000</td>
#       <td id="T_2d6ae_row9_col4" class="data row9 col4" >1.176241</td>
#       <td id="T_2d6ae_row9_col5" class="data row9 col5" >0.066432</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_2d6ae_row10_col0" class="data row10 col0" >CENTRAL ASIA</td>
#       <td id="T_2d6ae_row10_col1" class="data row10 col1" >106</td>
#       <td id="T_2d6ae_row10_col2" class="data row10 col2" >5</td>
#       <td id="T_2d6ae_row10_col3" class="data row10 col3" >80.400000</td>
#       <td id="T_2d6ae_row10_col4" class="data row10 col4" >1.318408</td>
#       <td id="T_2d6ae_row10_col5" class="data row10 col5" >0.062189</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_2d6ae_row11_col0" class="data row11 col0" >SOUTHEAST ASIA</td>
#       <td id="T_2d6ae_row11_col1" class="data row11 col1" >390</td>
#       <td id="T_2d6ae_row11_col2" class="data row11 col2" >25</td>
#       <td id="T_2d6ae_row11_col3" class="data row11 col3" >564.100000</td>
#       <td id="T_2d6ae_row11_col4" class="data row11 col4" >0.691367</td>
#       <td id="T_2d6ae_row11_col5" class="data row11 col5" >0.044318</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row12" class="row_heading level0 row12" >10</th>
#       <td id="T_2d6ae_row12_col0" class="data row12 col0" >SOUTH AMERICA</td>
#       <td id="T_2d6ae_row12_col1" class="data row12 col1" >562</td>
#       <td id="T_2d6ae_row12_col2" class="data row12 col2" >18</td>
#       <td id="T_2d6ae_row12_col3" class="data row12 col3" >425.000000</td>
#       <td id="T_2d6ae_row12_col4" class="data row12 col4" >1.322353</td>
#       <td id="T_2d6ae_row12_col5" class="data row12 col5" >0.042353</td>
#     </tr>
#     <tr>
#       <th id="T_2d6ae_level0_row13" class="row_heading level0 row13" >6</th>
#       <td id="T_2d6ae_row13_col0" class="data row13 col0" >MIDDLE AFRICA</td>
#       <td id="T_2d6ae_row13_col1" class="data row13 col1" >229</td>
#       <td id="T_2d6ae_row13_col2" class="data row13 col2" >8</td>
#       <td id="T_2d6ae_row13_col3" class="data row13 col3" >201.800000</td>
#       <td id="T_2d6ae_row13_col4" class="data row13 col4" >1.134787</td>
#       <td id="T_2d6ae_row13_col5" class="dat
